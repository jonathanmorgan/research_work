# %% [markdown]
# **2017.10.20 - work log - prelim_month_human - create Reliability_Names**

# %% [markdown]
#  # Table of Contents
# <div class="toc" style="margin-top: 1em;"><ul class="toc-item" id="toc-level0"><li><span><a href="https://research.local:8000/user/jonathanmorgan/notebooks/work/sourcenet/django/research/work/msu_phd_work/2017.10.20-work_log-prelim_month_human-create_Reliability_Names.ipynb#Setup" data-toc-modified-id="Setup-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Setup</a></span><ul class="toc-item"><li><span><a href="https://research.local:8000/user/jonathanmorgan/notebooks/work/sourcenet/django/research/work/msu_phd_work/2017.10.20-work_log-prelim_month_human-create_Reliability_Names.ipynb#Setup---Imports" data-toc-modified-id="Setup---Imports-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Setup - Imports</a></span></li><li><span><a href="https://research.local:8000/user/jonathanmorgan/notebooks/work/sourcenet/django/research/work/msu_phd_work/2017.10.20-work_log-prelim_month_human-create_Reliability_Names.ipynb#Setup---virtualenv-jupyter-kernel" data-toc-modified-id="Setup---virtualenv-jupyter-kernel-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Setup - virtualenv jupyter kernel</a></span></li><li><span><a href="https://research.local:8000/user/jonathanmorgan/notebooks/work/sourcenet/django/research/work/msu_phd_work/2017.10.20-work_log-prelim_month_human-create_Reliability_Names.ipynb#Setup---Initialize-Django" data-toc-modified-id="Setup---Initialize-Django-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Setup - Initialize Django</a></span></li></ul></li><li><span><a href="https://research.local:8000/user/jonathanmorgan/notebooks/work/sourcenet/django/research/work/msu_phd_work/2017.10.20-work_log-prelim_month_human-create_Reliability_Names.ipynb#Testing" data-toc-modified-id="Testing-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Testing</a></span></li><li><span><a href="https://research.local:8000/user/jonathanmorgan/notebooks/work/sourcenet/django/research/work/msu_phd_work/2017.10.20-work_log-prelim_month_human-create_Reliability_Names.ipynb#Reliability-data-creation---prelim_month_human" data-toc-modified-id="Reliability-data-creation---prelim_month_human-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Reliability data creation - <code>prelim_month_human</code></a></span><ul class="toc-item"><li><span><a href="https://research.local:8000/user/jonathanmorgan/notebooks/work/sourcenet/django/research/work/msu_phd_work/2017.10.20-work_log-prelim_month_human-create_Reliability_Names.ipynb#Create-Reliability_Names-for-prelim_month_human" data-toc-modified-id="Create-Reliability_Names-for-prelim_month_human-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Create <code>Reliability_Names</code> for <code>prelim_month_human</code></a></span></li></ul></li><li><span><a href="https://research.local:8000/user/jonathanmorgan/notebooks/work/sourcenet/django/research/work/msu_phd_work/2017.10.20-work_log-prelim_month_human-create_Reliability_Names.ipynb#Database-backup---sourcenet-2017.10.20.pg.sql.gz" data-toc-modified-id="Database-backup---sourcenet-2017.10.20.pg.sql.gz-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Database backup - <code>sourcenet-2017.10.20.pg.sql.gz</code></a></span></li><li><span><a href="https://research.local:8000/user/jonathanmorgan/notebooks/work/sourcenet/django/research/work/msu_phd_work/2017.10.20-work_log-prelim_month_human-create_Reliability_Names.ipynb#Data-cleanup" data-toc-modified-id="Data-cleanup-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Data cleanup</a></span><ul class="toc-item"><li><span><a href="https://research.local:8000/user/jonathanmorgan/notebooks/work/sourcenet/django/research/work/msu_phd_work/2017.10.20-work_log-prelim_month_human-create_Reliability_Names.ipynb#Remove-single-name-reliability-data" data-toc-modified-id="Remove-single-name-reliability-data-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Remove single-name reliability data</a></span><ul class="toc-item"><li><span><a href="https://research.local:8000/user/jonathanmorgan/notebooks/work/sourcenet/django/research/work/msu_phd_work/2017.10.20-work_log-prelim_month_human-create_Reliability_Names.ipynb#Single-name-data-assessment" data-toc-modified-id="Single-name-data-assessment-5.1.1"><span class="toc-item-num">5.1.1&nbsp;&nbsp;</span>Single-name data assessment</a></span></li><li><span><a href="https://research.local:8000/user/jonathanmorgan/notebooks/work/sourcenet/django/research/work/msu_phd_work/2017.10.20-work_log-prelim_month_human-create_Reliability_Names.ipynb#Delete-selected-single-name-data" data-toc-modified-id="Delete-selected-single-name-data-5.1.2"><span class="toc-item-num">5.1.2&nbsp;&nbsp;</span>Delete selected single-name data</a></span></li></ul></li></ul></li><li><span><a href="https://research.local:8000/user/jonathanmorgan/notebooks/work/sourcenet/django/research/work/msu_phd_work/2017.10.20-work_log-prelim_month_human-create_Reliability_Names.ipynb#Calculate-precision-and-recall" data-toc-modified-id="Calculate-precision-and-recall-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Calculate precision and recall</a></span></li><li><span><a href="https://research.local:8000/user/jonathanmorgan/notebooks/work/sourcenet/django/research/work/msu_phd_work/2017.10.20-work_log-prelim_month_human-create_Reliability_Names.ipynb#TODO" data-toc-modified-id="TODO-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>TODO</a></span></li></ul></div>

# %% [markdown]
# # Setup
#
# - Back to [Table of Contents](#Table-of-Contents)

# %% [markdown]
# ## Setup - Imports
#
# - Back to [Table of Contents](#Table-of-Contents)

# %%
import datetime
import six

print( "packages imported at " + str( datetime.datetime.now() ) )
# Out:
# packages imported at 2017-10-25 23:50:10.961295

# %% [markdown]
# ## Setup - virtualenv jupyter kernel
#
# - Back to [Table of Contents](#Table-of-Contents)
#
# If you are using a virtualenv, make sure that you:
#
# - have installed your virtualenv as a kernel.
# - choose the kernel for your virtualenv as the kernel for your notebook (Kernel --> Change kernel).
#
# Since I use a virtualenv, need to get that activated somehow inside this notebook.  One option is to run `../dev/wsgi.py` in this notebook, to configure the python environment manually as if you had activated the `sourcenet` virtualenv.  To do this, you'd make a code cell that contains:
#
#     %run ../dev/wsgi.py
#
# This is sketchy, however, because of the changes it makes to your Python environment within the context of whatever your current kernel is.  I'd worry about collisions with the actual Python 3 kernel.  Better, one can install their virtualenv as a separate kernel.  Steps:
#
# - activate your virtualenv:
#
#         workon sourcenet
#
# - in your virtualenv, install the package `ipykernel`.
#
#         pip install ipykernel
#
# - use the ipykernel python program to install the current environment as a kernel:
#
#         python -m ipykernel install --user --name <env_name> --display-name "<display_name>"
#
#     `sourcenet` example:
#
#         python -m ipykernel install --user --name sourcenet --display-name "sourcenet (Python 3)"
#
# More details: [http://ipython.readthedocs.io/en/stable/install/kernel_install.html](http://ipython.readthedocs.io/en/stable/install/kernel_install.html)

# %%
# %pwd
# Out:
# '/home/jonathanmorgan/work/sourcenet/django/research/work/msu_phd_work'

# %% [markdown]
# ## Setup - Initialize Django
#
# - Back to [Table of Contents](#Table-of-Contents)
#
# First, initialize my dev django project, so I can run code in this notebook that references my django models and can talk to the database using my project's settings.

# %%
# %run django_init.py
# Out:
# django initialized at 2017-10-26 03:50:14.391144

# %%
# django imports
from sourcenet.models import Article
from sourcenet.shared.sourcenet_base import SourcenetBase
from sourcenet_analysis.models import Reliability_Names
from sourcenet_analysis.reliability.coder_index_info import CoderIndexInfo
from sourcenet_analysis.reliability.index_info import IndexInfo
from sourcenet_analysis.reliability.index_helper import IndexHelper

# %% [markdown]
# # Testing
#
# - Back to [Table of Contents](#Table-of-Contents)
#
# I made big changes to support my human precision and recall.  Time to test...

# %%
# first, test the CoderIndexInfo
test_info = CoderIndexInfo( 4, None, 1, 5 )

# try getting user instance.
test_user_instance = test_info.get_coder_user_instance()

print( "Coder user: " + str( test_user_instance ) )
print( "test_info = " + str( test_info ) )
# Out:
# Coder user: jonathanmorgan
# test_info = user ID: 4, user instance: jonathanmorgan, index: 1, priority: 5

# %%
# create an index 1
test_index_info = IndexInfo()
test_index_info.set_index( 1 )

# configure as below:

# ...the ground truth user has highest priority (4) for index 1...
current_coder = SourcenetBase.get_ground_truth_coding_user()
current_coder_id = current_coder.id
current_priority = 4
add_status = test_index_info.add_coder( current_coder_id, priority_IN = current_priority )
print( ">>>> status = \"{status}\"".format( status = add_status ) )

# ...coder ID 8 is priority 3 for index 1...
current_coder_id = 8
current_index = 1
current_priority = 3
add_status = test_index_info.add_coder( current_coder_id, priority_IN = current_priority )
print( ">>>> status = \"{status}\"".format( status = add_status ) )

# ...coder ID 9 is priority 2 for index 1...
current_coder_id = 9
current_index = 1
current_priority = 2
add_status = test_index_info.add_coder( current_coder_id, priority_IN = current_priority )
print( ">>>> status = \"{status}\"".format( status = add_status ) )

# ...coder ID 10 is priority 1 for index 1...
current_coder_id = 10
current_index = 1
current_priority = 1
add_status = test_index_info.add_coder( current_coder_id, priority_IN = current_priority )
print( ">>>> status = \"{status}\"".format( status = add_status ) )

print( "index info: " + str( test_index_info ) )

test_id_to_info_map = test_index_info.get_coder_id_to_info_map()
for coder_user_id, coder_info in six.iteritems( test_id_to_info_map ):
    
    print( "--> coder id: " + str( coder_user_id ) + " = " + str( coder_info ) )
    
#-- END loop over coders in index. --#
# Out:
# >>>> status = ""
# >>>> status = ""
# >>>> status = ""
# >>>> status = ""
# index info: index: 1
# ====>coder info: {8: <sourcenet_analysis.reliability.coder_index_info.CoderIndexInfo object at 0x7f686fd17dd8>, 9: <sourcenet_analysis.reliability.coder_index_info.CoderIndexInfo object at 0x7f686fd17ef0>, 10: <sourcenet_analysis.reliability.coder_index_info.CoderIndexInfo object at 0x7f686fd17da0>, 13: <sourcenet_analysis.reliability.coder_index_info.CoderIndexInfo object at 0x7f686fd17c50>}
# --> coder id: 8 = user ID: 8, user instance: minnesota1, index: 1, priority: 3
# --> coder id: 9 = user ID: 9, user instance: minnesota2, index: 1, priority: 2
# --> coder id: 10 = user ID: 10, user instance: minnesota3, index: 1, priority: 1
# --> coder id: 13 = user ID: 13, user instance: ground_truth, index: 1, priority: 4

# %%
# create index helper.
test_index_helper = IndexHelper()

# is valid index?
print( test_index_helper.is_index_valid( 0 ) )
print( test_index_helper.is_index_valid( 1 ) )
print( test_index_helper.is_index_valid( 5 ) )
print( test_index_helper.is_index_valid( 10 ) )
print( test_index_helper.is_index_valid( 15 ) )
# Out:
# False
# True
# True
# True
# False

# %%
# create index helper.
#test_index_helper = IndexHelper()

# ==> Index 1: human plus ground truth - set it up so that...

# configure as below:

# ...the ground truth user has highest priority (4) for index 1...
current_coder = SourcenetBase.get_ground_truth_coding_user()
current_coder_id = current_coder.id
current_index = 1
current_priority = 4
add_status = test_index_helper.add_coder_at_index( current_coder_id, current_index, priority_IN = current_priority )
print( ">>>> status = \"{status}\"\n\n".format( status = add_status ) )

# ...coder ID 8 is priority 3 for index 1...
current_coder_id = 8
current_index = 1
current_priority = 3
add_status = test_index_helper.add_coder_at_index( current_coder_id, current_index, priority_IN = current_priority )
print( ">>>> status = \"{status}\"\n\n".format( status = add_status ) )

# ...coder ID 9 is priority 2 for index 1...
current_coder_id = 9
current_index = 1
current_priority = 2
add_status = test_index_helper.add_coder_at_index( current_coder_id, current_index, priority_IN = current_priority )
print( ">>>> status = \"{status}\"\n\n".format( status = add_status ) )

# ...coder ID 10 is priority 1 for index 1...
current_coder_id = 10
current_index = 1
current_priority = 1
add_status = test_index_helper.add_coder_at_index( current_coder_id, current_index, priority_IN = current_priority )
print( ">>>> status = \"{status}\"\n\n".format( status = add_status ) )

# ==> Index 2: human (not ground truth) - set it up so that...

# coder ID 8 is priority 3 for index 2...
current_coder_id = 8
current_index = 2
current_priority = 3
add_status = test_index_helper.add_coder_at_index( current_coder_id, current_index, priority_IN = current_priority )
print( ">>>> status = \"{status}\"\n\n".format( status = add_status ) )

# ...coder ID 9 is priority 2 for index 2...
current_coder_id = 9
current_index = 2
current_priority = 2
add_status = test_index_helper.add_coder_at_index( current_coder_id, current_index, priority_IN = current_priority )
print( ">>>> status = \"{status}\"\n\n".format( status = add_status ) )

# ...coder ID 10 is priority 1 for index 2...
current_coder_id = 10
current_index = 2
current_priority = 1
add_status = test_index_helper.add_coder_at_index( current_coder_id, current_index, priority_IN = current_priority )
print( ">>>> status = \"{status}\"\n\n".format( status = add_status ) )


print( "\n>>>> index helper: " + str( test_index_helper ) )
print( "\n>>>> index info map: " + str( test_index_helper.m_index_to_info_map ) )

test_index_to_info_map = test_index_helper.get_index_to_info_map()

print( "\n>>>> index info map: " + str( test_index_to_info_map ) )
print( "\n" )

for current_index, index_info in six.iteritems( test_index_to_info_map ):
    
    print( "--> we;ll see...? : " + str( current_index ) + " = " + str( index_info ) )
    
#-- END loop over coders in index. --#
# Out:
# >>>> status = ""
#
#
# >>>> status = ""
#
#
# >>>> status = ""
#
#
# >>>> status = ""
#
#
# >>>> status = ""
#
#
# >>>> status = ""
#
#
# >>>> status = ""
#
#
#
# >>>> index helper: index-info-map: {1: <sourcenet_analysis.reliability.index_info.IndexInfo object at 0x7f686fd14a58>, 2: <sourcenet_analysis.reliability.index_info.IndexInfo object at 0x7f686fd14e10>}
#
# >>>> index info map: {1: <sourcenet_analysis.reliability.index_info.IndexInfo object at 0x7f686fd14a58>, 2: <sourcenet_analysis.reliability.index_info.IndexInfo object at 0x7f686fd14e10>}
#
# >>>> index info map: {1: <sourcenet_analysis.reliability.index_info.IndexInfo object at 0x7f686fd14a58>, 2: <sourcenet_analysis.reliability.index_info.IndexInfo object at 0x7f686fd14e10>}
#
#
# --> we;ll see...? : 1 = index: 1
# ====>coder info: {8: <sourcenet_analysis.reliability.coder_index_info.CoderIndexInfo object at 0x7f686fd14f28>, 9: <sourcenet_analysis.reliability.coder_index_info.CoderIndexInfo object at 0x7f686fd14b38>, 10: <sourcenet_analysis.reliability.coder_index_info.CoderIndexInfo object at 0x7f686fd14cf8>, 13: <sourcenet_analysis.reliability.coder_index_info.CoderIndexInfo object at 0x7f686fd14b00>}
# --> we;ll see...? : 2 = index: 2
# ====>coder info: {8: <sourcenet_analysis.reliability.coder_index_info.CoderIndexInfo object at 0x7f686fd14c88>, 9: <sourcenet_analysis.reliability.coder_index_info.CoderIndexInfo object at 0x7f686fd14b70>, 10: <sourcenet_analysis.reliability.coder_index_info.CoderIndexInfo object at 0x7f686fd14cc0>}

# %%
index_1_coder = test_index_helper.get_coder_for_index( 1 )
index_2_coder = test_index_helper.get_coder_for_index( 2 )

print( "index 1 coder: {coder1}".format( coder1 = index_1_coder ) )
print( "index 2 coder: {coder2}".format( coder2 = index_2_coder ) )
# Out:
# ++++ found User: ground_truth
# ++++ found User: minnesota1
# index 1 coder: ground_truth
# index 2 coder: minnesota1

# %%
#article_id = 20813
article_id = 20722
article_instance = Article.objects.get( id = article_id )
coder_map = test_index_helper.map_index_to_coder_for_article( article_instance )
print( "Coder map: {coder_map}".format( coder_map = str( coder_map ) ) )
# Out:
# Coder map: {1: <User: minnesota1>, 2: <User: minnesota1>}

# %%
# get all Reliability_Names with label = "prelim_month_human".
reliability_names_qs = Reliability_Names.objects.filter( label = "prelim_month_human" )
item_count = reliability_names_qs.count()
print( "prelim_month_human count = " + str( item_count ) )
do_delete = False
if ( ( item_count > 0 ) and ( do_delete == True ) ):
    
    for instance in reliability_names_qs:

        # delete.
        instance.delete()

    #-- END loop --#
    
#-- END check to see if anything to delete. --#
# Out:
# prelim_month_human count = 0

# %% [markdown]
# # Reliability data creation - `prelim_month_human`
#
# - Back to [Table of Contents](#Table-of-Contents)
#
# Plan:
#
# - create Reliability_Names data for ground_truth plus human coders in index 1, human coders without ground_truth in index 2.
# - remove single names.
# - calculate precision and recall on humans against ground truth.

# %% [markdown]
# ## Create `Reliability_Names` for `prelim_month_human`
#
# - Back to [Table of Contents](#Table-of-Contents)

# %% [markdown]
# First, check to see if the label "`prelim_month_human`" is in use:
#
#     SELECT DISTINCT label
#     FROM sourcenet_analysis_reliability_names
#     ORDER BY label ASC;
#
# Results:
#
#     name_data_test_combined_human
#     prelim_month
#     prelim_month_exclude
#     prelim_network
#     prelim_network_combined
#     prelim_reliability
#     prelim_reliability_combined_all
#     prelim_reliability_combined_all_final
#     prelim_reliability_combined_human
#     prelim_reliability_combined_human_final
#     prelim_reliability_test
#     prelim_reliability_test_all
#     prelim_reliability_test_human
#     prelim_reliability_v2
#     prelim_training_002
#     prelim_training_003
#
# Not in use.

# %% [markdown]
# Now, run code to actually build the Reliability_Names.

# %%
from __future__ import unicode_literals

# django imports
from django.contrib.auth.models import User

# sourcenet imports
from sourcenet.shared.sourcenet_base import SourcenetBase

# sourcenet_analysis imports
from sourcenet_analysis.reliability.reliability_names_builder import ReliabilityNamesBuilder

# declare variables
my_reliability_instance = None
tag_list = None
label = ""
do_work = True

# declare variables - user setup
current_coder = None
current_coder_id = -1
current_index = -1
current_priority = -1

# declare variables - Article_Data filtering.
coder_type = ""

# make reliability instance
my_reliability_instance = ReliabilityNamesBuilder()

#===============================================================================
# configure
#===============================================================================

# list of tags of articles we want to process.
tag_list = [ "grp_month", ]

# label to associate with results, for subsequent lookup.
label = "prelim_month_human"

# ! ====> map coders to indices

# ==> Index 1: set it up so that...

# ...the ground truth user has highest priority (4) for index 1...
current_coder = SourcenetBase.get_ground_truth_coding_user()
current_coder_id = current_coder.id
current_index = 1
current_priority = 4
my_reliability_instance.add_coder_at_index( current_coder_id, current_index, priority_IN = current_priority )

# ...coder ID 8 is priority 3 for index 1...
current_coder_id = 8
current_index = 1
current_priority = 3
my_reliability_instance.add_coder_at_index( current_coder_id, current_index, priority_IN = current_priority )

# ...coder ID 9 is priority 2 for index 1...
current_coder_id = 9
current_index = 1
current_priority = 2
my_reliability_instance.add_coder_at_index( current_coder_id, current_index, priority_IN = current_priority )

# ...coder ID 10 is priority 1 for index 1...
current_coder_id = 10
current_index = 1
current_priority = 1
my_reliability_instance.add_coder_at_index( current_coder_id, current_index, priority_IN = current_priority )

# ==> Index 2: human (not ground truth) - set it up so that...

# coder ID 8 is priority 3 for index 2...
current_coder_id = 8
current_index = 2
current_priority = 3
my_reliability_instance.add_coder_at_index( current_coder_id, current_index, priority_IN = current_priority )

# ...coder ID 9 is priority 2 for index 2...
current_coder_id = 9
current_index = 2
current_priority = 2
my_reliability_instance.add_coder_at_index( current_coder_id, current_index, priority_IN = current_priority )

# ...coder ID 10 is priority 1 for index 2...
current_coder_id = 10
current_index = 2
current_priority = 1
my_reliability_instance.add_coder_at_index( current_coder_id, current_index, priority_IN = current_priority )

# and only look at coding by those users.

# output debug JSON to file
#my_reliability_instance.debug_output_json_file_path = "/home/jonathanmorgan/" + label + ".json"
# Out:
# ''

# %%
print( "index_helper: {helper_instance}".format( helper_instance = str( my_reliability_instance.get_index_helper() ) ) )
# Out:
# index_helper: index-info-map: {1: <sourcenet_analysis.reliability.index_info.IndexInfo object at 0x7f686f48d898>, 2: <sourcenet_analysis.reliability.index_info.IndexInfo object at 0x7f686f48def0>}

# %%
article_id = 20813
#article_id = 20722
article_instance = Article.objects.get( id = article_id )
coder_map = my_reliability_instance.map_index_to_coder_for_article( article_instance )
print( "Coder map: {coder_map}".format( coder_map = str( coder_map ) ) )
# Out:
# Coder map: {1: <User: ground_truth>, 2: <User: minnesota3>}

# %%
#===============================================================================
# process articles
#===============================================================================

do_work = True
if ( do_work == True ):

    # process articles
    my_reliability_instance.process_articles( tag_list )

    # output to database.
    #my_reliability_instance.output_reliability_data( label )

    print( "reliability data created at " + str( datetime.datetime.now() ) )
    
#-- END check to see if we do work. --#
# Out:
# - Article ID: 20645; Article_Data count: 3
# ---- - Article Data Info: 2322 - minnesota1 - no coder_type -- Article: 20645 - Dec 01, 2009, City and Region ( A9 ), UID: 12C59C4F54978BA0 - Reductions proposed for clerk's office staff - Cuts could be made without layoffs, manager says ( Grand Rapids Press, The )
# ---- - Article Data Info: 2350 - minnesota3 - no coder_type -- Article: 20645 - Dec 01, 2009, City and Region ( A9 ), UID: 12C59C4F54978BA0 - Reductions proposed for clerk's office staff - Cuts could be made without layoffs, manager says ( Grand Rapids Press, The )
# ---- - Article Data Info: 2454 - minnesota2 - no coder_type -- Article: 20645 - Dec 01, 2009, City and Region ( A9 ), UID: 12C59C4F54978BA0 - Reductions proposed for clerk's office staff - Cuts could be made without layoffs, manager says ( Grand Rapids Press, The )
# - Article ID: 20647; Article_Data count: 1
# ---- - Article Data Info: 2355 - minnesota3 - no coder_type -- Article: 20647 - Dec 01, 2009, City and Region ( A3 ), UID: 12C59C4F5C9611C8 - Students sing to move others, make a difference - Teachers aim to instill sense of empowerment ( Grand Rapids Press, The )
# - Article ID: 20653; Article_Data count: 3
# ---- - Article Data Info: 2323 - minnesota1 - no coder_type -- Article: 20653 - Dec 01, 2009, City and Region ( A9 ), UID: 12C59C4F59D213B0 - School officials hope for federal grant - State legislation needed before schools can qualify ( Grand Rapids Press, The )
# ---- - Article Data Info: 2351 - minnesota3 - no coder_type -- Article: 20653 - Dec 01, 2009, City and Region ( A9 ), UID: 12C59C4F59D213B0 - School officials hope for federal grant - State legislation needed before schools can qualify ( Grand Rapids Press, The )
# - Article ID: 24078; Article_Data count: 1
# ---- - Article Data Info: 2798 - minnesota3 - no coder_type -- Article: 24078 - Dec 31, 2009, City and Region ( A3 ), UID: 12CF437D5D8AF530 - State reform tests school leaders - GRPS, union officials scramble to grasp details tied to federal funds ( Grand Rapids Press, The )
# - Article ID: 24082; Article_Data count: 1
# ---- - Article Data Info: 2799 - minnesota3 - no coder_type -- Article: 24082 - Dec 31, 2009, Business ( A6 ), UID: 12CF437D688FB678 - Vintage success story - Scholars from India turn hard work, customer service into a healthy business ( Grand Rapids Press, The )
# - Article ID: 24111; Article_Data count: 1
# ---- - Article Data Info: 2800 - minnesota3 - no coder_type -- Article: 24111 - Dec 31, 2009, Front Page ( A1 ), UID: 12CF437D0B7676A8 - Brother feared tragic end - Man killed by freight train suffered many problems shared by homeless ( Grand Rapids Press, The )
# - Article ID: 24115; Article_Data count: 1
# ---- - Article Data Info: 2628 - minnesota1 - no coder_type -- Article: 24115 - Dec 31, 2009, City and Region ( A12 ), UID: 12CF437D1E8552F0 - Drivers urged to stay sober, watch for snow-slick roads - Extra patrols will be out through the weekend ( Grand Rapids Press, The )
# - Article ID: 24116; Article_Data count: 1
# ---- - Article Data Info: 2755 - minnesota2 - no coder_type -- Article: 24116 - Dec 31, 2009, Front Page ( A1 ), UID: 12CF437D38CAB240 - Lost appeal pushes Rockford lawsuit to state Supreme Court - City Council members intend to continue crusade to secure a District
# Court for city
#  ( Grand Rapids Press, The )
# - Article ID: 24131; Article_Data count: 2
# ---- - Article Data Info: 2629 - minnesota1 - no coder_type -- Article: 24131 - Dec 31, 2009, Front Page ( A1 ), UID: 12CF437D33F91978 - Hotels, businesses brace for influx of celebrating people ( Grand Rapids Press, The )
# ---- - Article Data Info: 3415 - ground_truth - no coder_type -- Article: 24131 - Dec 31, 2009, Front Page ( A1 ), UID: 12CF437D33F91978 - Hotels, businesses brace for influx of celebrating people ( Grand Rapids Press, The )
# - Article ID: 24132; Article_Data count: 2
# ---- - Article Data Info: 2801 - minnesota3 - no coder_type -- Article: 24132 - Dec 31, 2009, City and Region ( A3 ), UID: 12CF437D6BFB56A0 - Woman dies in van-pickup crash - She was transporting a handicapped patient to an appointment ( Grand Rapids Press, The )
# ---- - Article Data Info: 3416 - ground_truth - no coder_type -- Article: 24132 - Dec 31, 2009, City and Region ( A3 ), UID: 12CF437D6BFB56A0 - Woman dies in van-pickup crash - She was transporting a handicapped patient to an appointment ( Grand Rapids Press, The )
# reliability data created at 2017-10-26 03:51:01.387459

# %%
#===============================================================================
# output data
#===============================================================================

do_work = True
if ( do_work == True ):

    # process articles
    #my_reliability_instance.process_articles( tag_list )

    # output to database.
    my_reliability_instance.output_reliability_data( label )

    print( "reliability data created at " + str( datetime.datetime.now() ) )
    
#-- END check to see if we do work. --#
# Out:
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - author: 13824 - label: prelim_month_human - article ID: 23555 - Chris Knape ( 74 ) - coders: [1][2]:  ==> [1] - coder=9; detected=1; person=74 ==> [2] - coder=9; detected=1; person=74
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - source: 13825 - label: prelim_month_human - article ID: 23555 - Varinia Del Barrio ( 2566 ) - coders: [1][2]:  ==> [1] - coder=9; detected=1; person=2566 ==> [2] - coder=9; detected=1; person=2566
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - source: 13826 - label: prelim_month_human - article ID: 23555 - Fidel Castro ( 2565 ) - coders: [1][2]:  ==> [1] - coder=9; detected=1; person=2565 ==> [2] - coder=9; detected=1; person=2565
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - source: 13827 - label: prelim_month_human - article ID: 23555 - Ida Duque ( 2254 ) - coders: [1][2]:  ==> [1] - coder=9; detected=1; person=2254 ==> [2] - coder=9; detected=1; person=2254
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - author: 13828 - label: prelim_month_human - article ID: 21509 - Nate Reens ( 46 ) - coders: [1][2]:  ==> [1] - coder=9; detected=1; person=46 ==> [2] - coder=9; detected=1; person=46
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - source: 13829 - label: prelim_month_human - article ID: 21509 - Charlene Hernandez ( 876 ) - coders: [1][2]:  ==> [1] - coder=9; detected=1; person=876 ==> [2] - coder=9; detected=1; person=876
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - source: 13830 - label: prelim_month_human - article ID: 21509 - Frances Estrada ( 180 ) - coders: [1][2]:  ==> [1] - coder=9; detected=1; person=180 ==> [2] - coder=9; detected=1; person=180
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - source: 13831 - label: prelim_month_human - article ID: 21509 - Jonathan Brito ( 181 ) - coders: [1][2]:  ==> [1] - coder=9; detected=1; person=181 ==> [2] - coder=9; detected=1; person=181
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - source: 13832 - label: prelim_month_human - article ID: 21509 - Jerry Salatka ( 182 ) - coders: [1][2]:  ==> [1] - coder=9; detected=1; person=182 ==> [2] - coder=9; detected=1; person=182
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - author: 13833 - label: prelim_month_human - article ID: 23559 - David L. DeBruyn ( 2567 ) - coders: [1][2]:  ==> [1] - coder=9; detected=1; person=2567 ==> [2] - coder=9; detected=1; person=2567
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - author: 13834 - label: prelim_month_human - article ID: 21512 - Monica Scott ( 178 ) - coders: [1][2]:  ==> [1] - coder=10; detected=1; person=178 ==> [2] - coder=10; detected=1; person=178
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - source: 13835 - label: prelim_month_human - article ID: 21512 - Mike Nystrom ( 179 ) - coders: [1][2]:  ==> [1] - coder=10; detected=1; person=179 ==> [2] - coder=10; detected=1; person=179
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - author: 13836 - label: prelim_month_human - article ID: 23562 - Chris Knape ( 74 ) - coders: [1][2]:  ==> [1] - coder=9; detected=1; person=74 ==> [2] - coder=9; detected=1; person=74
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - source: 13837 - label: prelim_month_human - article ID: 23562 - Varinia Del Barrio ( 2566 ) - coders: [1][2]:  ==> [1] - coder=9; detected=1; person=2566 ==> [2] - coder=9; detected=1; person=2566
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - source: 13838 - label: prelim_month_human - article ID: 23562 - Fidel Castro ( 2565 ) - coders: [1][2]:  ==> [1] - coder=9; detected=1; person=2565 ==> [2] - coder=9; detected=1; person=2565
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - source: 13839 - label: prelim_month_human - article ID: 23562 - Ida Duque ( 2254 ) - coders: [1][2]:  ==> [1] - coder=9; detected=1; person=2254 ==> [2] - coder=9; detected=1; person=2254
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - author: 13840 - label: prelim_month_human - article ID: 21515 - Brian McVicar ( 66 ) - coders: [1][2]:  ==> [1] - coder=13; detected=1; person=66 ==> [2] - coder=8; detected=1; person=66
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - source: 13841 - label: prelim_month_human - article ID: 21515 - Joyce Bos ( 392 ) - coders: [1][2]:  ==> [1] - coder=13; detected=1; person=392 ==> [2] - coder=8; detected=1; person=392
# ----> In output_reliability_name_row: len( index_used_list ) = 1; list = [1]
# - source: 13842 - label: prelim_month_human - article ID: 21515 - Karen Roback ( 393 ) - coders: [1][2]:  ==> [1] - coder=13; detected=1; person=393 ==> [2] - coder=8; detected=0; person=0
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - author: 13843 - label: prelim_month_human - article ID: 21677 - Nate Reens ( 46 ) - coders: [1][2]:  ==> [1] - coder=8; detected=1; person=46 ==> [2] - coder=8; detected=1; person=46
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - source: 13844 - label: prelim_month_human - article ID: 21677 - Shawn Michael Godfrey ( 24 ) - coders: [1][2]:  ==> [1] - coder=8; detected=1; person=24 ==> [2] - coder=8; detected=1; person=24
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - source: 13845 - label: prelim_month_human - article ID: 21677 - Lee Craddock ( 770 ) - coders: [1][2]:  ==> [1] - coder=8; detected=1; person=770 ==> [2] - coder=8; detected=1; person=770
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - source: 13846 - label: prelim_month_human - article ID: 21677 - Jeremy Gentz ( 932 ) - coders: [1][2]:  ==> [1] - coder=8; detected=1; person=932 ==> [2] - coder=8; detected=1; person=932
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - source: 13847 - label: prelim_month_human - article ID: 21677 - Denise Bentley ( 485 ) - coders: [1][2]:  ==> [1] - coder=8; detected=1; person=485 ==> [2] - coder=8; detected=1; person=485
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - author: 13848 - label: prelim_month_human - article ID: 22546 - Julie Makarewicz ( 30 ) - coders: [1][2]:  ==> [1] - coder=9; detected=1; person=30 ==> [2] - coder=9; detected=1; person=30
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - source: 13849 - label: prelim_month_human - article ID: 22546 - Craig Bierenga ( 2443 ) - coders: [1][2]:  ==> [1] - coder=9; detected=1; person=2443 ==> [2] - coder=9; detected=1; person=2443
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - source: 
) - coders: [1][2]:  ==> [1] - coder=10; detected=1; person=2398 ==> [2] - coder=10; detected=1; person=2398
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - source: 13875 - label: prelim_month_human - article ID: 22551 - Meghan Aupperlee ( 2399 ) - coders: [1][2]:  ==> [1] - coder=10; detected=1; person=2399 ==> [2] - coder=10; detected=1; person=2399
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - author: 13876 - label: prelim_month_human - article ID: 23577 - Cris Greer ( 598 ) - coders: [1][2]:  ==> [1] - coder=9; detected=1; person=598 ==> [2] - coder=9; detected=1; person=598
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - source: 13877 - label: prelim_month_human - article ID: 23577 - Augie Mata ( 2593 ) - coders: [1][2]:  ==> [1] - coder=9; detected=1; person=2593 ==> [2] - coder=9; detected=1; person=2593
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - source: 13878 - label: prelim_month_human - article ID: 23577 - Yale Pope ( 2594 ) - coders: [1][2]:  ==> [1] - coder=9; detected=1; person=2594 ==> [2] - coder=9; detected=1; person=2594
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - author: 13879 - label: prelim_month_human - article ID: 22554 - John Tunison ( 84 ) - coders: [1][2]:  ==> [1] - coder=8; detected=1; person=84 ==> [2] - coder=8; detected=1; person=84
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - source: 13880 - label: prelim_month_human - article ID: 22554 - Guy Pruitt ( 1872 ) - coders: [1][2]:  ==> [1] - coder=8; detected=1; person=1872 ==> [2] - coder=8; detected=1; person=1872
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - source: 13881 - label: prelim_month_human - article ID: 22554 - Dan Hopkins ( 1873 ) - coders: [1][2]:  ==> [1] - coder=8; detected=1; person=1873 ==> [2] - coder=8; detected=1; person=1873
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - source: 13882 - label: prelim_month_human - article ID: 22554 - Amanda Putnam ( 1874 ) - coders: [1][2]:  ==> [1] - coder=8; detected=1; person=1874 ==> [2] - coder=8; detected=1; person=1874
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - author: 13883 - label: prelim_month_human - article ID: 23580 - Myron Kukla ( 599 ) - coders: [1][2]:  ==> [1] - coder=10; detected=1; person=599 ==> [2] - coder=10; detected=1; person=599
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - source: 13884 - label: prelim_month_human - article ID: 23580 - Joe Meckley ( 2684 ) - coders: [1][2]:  ==> [1] - coder=10; detected=1; person=2684 ==> [2] - coder=10; detected=1; person=2684
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - source: 13885 - label: prelim_month_human - article ID: 23580 - Joel Genzink ( 2685 ) - coders: [1][2]:  ==> [1] - coder=10; detected=1; person=2685 ==> [2] - coder=10; detected=1; person=2685
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - source: 13886 - label: prelim_month_human - article ID: 23580 - Ross Bouwkamp ( 2686 ) - coders: [1][2]:  ==> [1] - coder=10; detected=1; person=2686 ==> [2] - coder=10; detected=1; person=2686
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - author: 13887 - label: prelim_month_human - article ID: 21338 - Dave Murray ( 69 ) - coders: [1][2]:  ==> [1] - coder=13; detected=1; person=69 ==> [2] - coder=10; detected=1; person=69
# ----> In output_reliability_name_row: len( index_used_list ) = 1; list = [1]
# - source: 13888 - label: prelim_month_human - article ID: 21338 - Hollie Rademacher ( 832 ) - coders: [1][2]:  ==> [1] - coder=13; detected=1; person=832 ==> [2] - coder=10; detected=0; person=0
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - source: 13889 - label: prelim_month_human - article ID: 21338 - Tom Rademacher ( 340 ) - coders: [1][2]:  ==> [1] - coder=13; detected=1; person=340 ==> [2] - coder=10; detected=1; person=340
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - author: 13890 - label: prelim_month_human - article ID: 24069 - John Tunison ( 84 ) - coders: [1][2]:  ==> [1] - coder=9; detected=1; person=84 ==> [2] - coder=9; detected=1; person=84
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - source: 13891 - label: prelim_month_human - article ID: 24069 - James DeVries ( 2667 ) - coders: [1][2]:  ==> [1] - coder=9; detected=1; person=2667 ==> [2] - coder=9; detected=1; person=2667
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - source: 13892 - label: prelim_month_human - article ID: 24069 - Dana DeVries ( 2668 ) - coders: [1][2]:  ==> [1] - coder=9; detected=1; person=2668 ==> [2] - coder=9; detected=1; person=2668
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - source: 13893 - label: prelim_month_human - article ID: 24069 - Brad Knoll ( 2669 ) - coders: [1][2]:  ==> [1] - coder=9; detected=1; person=2669 ==> [2] - coder=9; detected=1; person=2669
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - source: 13894 - label: prelim_month_human - article ID: 24069 - Denny Edwards ( 2670 ) - coders: [1][2]:  ==> [1] - coder=9; detected=1; person=2670 ==> [2] - coder=9; detected=1; person=2670
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - author: 13895 - label: prelim_month_human - article ID: 21536 - Ron Cammel ( 29 ) - coders: [1][2]:  ==> [1] - coder=10; detected=1; person=29 ==> [2] - coder=10; detected=1; person=29
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - source: 13896 - label: prelim_month_human - article ID: 21536 - Robert Homan ( 386 ) - coders: [1][2]:  ==> [1] - coder=10; detected=1; person=386 ==> [2] - coder=10; detected=1; person=386
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - author: 13897 - label: prelim_month_human - article ID: 23899 - Nardy Baeza Bickel ( 161 ) - coders: [1][2]:  ==> [1] - coder=10; detected=1; person=161 ==> [2] - coder=10; detected=1; person=161
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - source: 13898 - label: prelim_month_human - article ID: 23899 - Terry Wolfgang ( 2728 ) - coders: [1][2]:  ==> [1] - coder=10; detected=1; person=2728 ==> [2] - coder=10; detected=1; person=2728
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - source: 13899 - label: prelim_month_human - article ID: 23899 - Jennifer Granholm ( 102 ) - coders: [1][2]:  ==> [1] - coder=10; detected=1; person=102 ==> [2] - coder=10; detected=1; person=102
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - source: 13900 - label: prelim_month_human - article ID: 23899 - Jill Wallace ( 558 ) - coders: [1][2]:  ==> [1] - coder=10; detected=1; person=558 ==> [2] - coder=10; detected=1; person=558
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - author: 13901 - label: prelim_month_human - article ID: 21542 - Kym Reinstadler ( 377 ) - coders: [1][2]:  ==> [1] - coder=9; detected=1; person=377 ==> [2] - coder=9; detected=1; person=377
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - source: 13902 - label: prelim_month_human - article ID: 21542 - Paul Streelman ( 378 ) - coders: [1][2]:  ==> [1] - coder=9; detected=1; person=378 ==> [2] - coder=9; detected=1; person=378
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - author: 13903 - label: prelim_month_human - article ID: 22567 - Barton Deiters ( 23 ) - coders: [1][2]:  ==> [1] - coder=10; detected=1; person=23 ==> [2] - coder=10; detected=1; person=23
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - source: 13904 - label: prelim_month_human - article ID: 22567 - Steven Timmers ( 2136 ) - coders: [1][2]:  ==> [1] - coder=10; detected=1; person=2136 ==> [2] - coder=10; detected=1; person=2136
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - source: 13905 - label: prelim_month_human - article ID: 22567 - Charles Judson Holbrook ( 2403 ) - coders: [1][2]:  ==> [1] - coder=10; detected=1; person=2403 ==> [2] - coder=10; detected=1; person=2403
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - author: 13906 - label: prelim_month_human - article ID: 21549 - Shandra Martinez ( 36 ) - coders: [1][2]:  ==> [1] - coder=8; detected=1; person=36 ==> [2] - coder=8; detected=1; person=36
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - source: 13907 - label: prelim_month_human - article ID: 21549 - Art Shannon ( 408 ) - coders: [1][2]:  ==> [1] - coder=8; detected=1; person=408 ==> [2] - coder=8; detected=1; person=408
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - source: 13908 - label: prelim_month_human - article ID: 21549 - Elaine Monarch ( 405 ) - coders: [1][2]:  ==> [1] - coder=8; detected=1; person=405 ==> [2] - coder=8; detected=1; person=405
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - source: 13909 - label: prelim_month_human - article ID: 21549 - James Bishop ( 406 ) - coders: [1][2]:  ==> [1] - coder=8; detected=1; person=406 ==> [2] - coder=8; detected=1; person=406
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - source: 13910 - label: prelim_month_human - article ID: 21549 - Sara Uekert ( 407 ) - coders: [1][2]:  ==> [1] - coder=8; detected=1; person=407 ==> [2] - coder=8; detected=1; person=407
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - author: 13911 - label: prelim_month_human - article ID: 21551 - John Tunison ( 84 ) - coders: [1][2]:  ==> [1] - coder=13; detected=1; person=84 ==> [2] - coder=8; detected=1; person=84
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - source: 13912 - label: prelim_month_human - article ID: 21551 - Anthony Black ( 345 ) - coders: [1][2]:  ==> [1] - coder=13; detected=1; person=345 ==> [2] - coder=8; detected=1; person=345
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - source: 13913 - label: prelim_month_human - article ID: 21551 - Bruce Schedlbauer ( 346 ) - coders: [1][2]:  ==> [1] - coder=13; detected=1; person=346 ==> [2] - coder=8; detected=1; person=346
# ----> In output_reliability_name_row: len( index_used_list ) = 1; list = [2]
# - source: 13914 - label: prelim_month_human - article ID: 21551 - Gerald R. Ford ( 839 ) - coders: [1][2]:  ==> [1] - coder=13; detected=0; person=0 ==> [2] - coder=8; detected=1; person=839
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - author: 13915 - label: prelim_month_human - article ID: 21557 - Ron Cammel ( 29 ) - coders: [1][2]:  ==> [1] - coder=13; detected=1; person=29 ==> [2] - coder=10; detected=1; person=29
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - source: 13916 - label: prelim_month_human - article ID: 21557 - Marty Alexander ( 384 ) - coders: [1][2]:  ==> [1] - coder=13; detected=1; person=384 ==> [2] - coder=10; detected=1; person=384
# ----> In output_reliability_name_row: len( index_used_list ) = 1; list = [1]
# - source: 13917 - label: prelim_month_human - article ID: 21557 - Paul Huizen ( 385 ) - coders: [1][2]:  ==> [1] - coder=13; detected=1; person=385 ==> [2] - coder=10; detected=0; person=0
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - source: 13918 - label: prelim_month_human - article ID: 21557 - Rich Salo ( 381 ) - coders: [1][2]:  ==> [1] - coder=13; detected=1; person=381 ==> [2] - coder=10; detected=1; person=381
# ----> In output_reliability_name_row: len( index_used_list ) = 1; list = [1]
# - source: 13919 - label: prelim_month_human - article ID: 21557 - Robert Howe ( 382 ) - coders: [1][2]:  ==> [1] - coder=13; detected=1; person=382 ==> [2] - coder=10; detected=0; person=0
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - source: 13920 - label: prelim_month_human - article ID: 21557 - Kevin O'Neill ( 383 ) - coders: [1][2]:  ==> [1] - coder=13; detected=1; person=383 ==> [2] - coder=10; detected=1; person=383
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - author: 13921 - label: prelim_month_human - article ID: 22587 - Aaron Ogg ( 425 ) - coders: [1][2]:  ==> [1] - coder=8; detected=1; person
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - source: 13971 - label: prelim_month_human - article ID: 23223 - Ben Baird ( 2515 ) - coders: [1][2]:  ==> [1] - coder=9; detected=1; person=2515 ==> [2] - coder=9; detected=1; person=2515
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - source: 13972 - label: prelim_month_human - article ID: 23223 - James Fowler ( 2516 ) - coders: [1][2]:  ==> [1] - coder=9; detected=1; person=2516 ==> [2] - coder=9; detected=1; person=2516
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - source: 13973 - label: prelim_month_human - article ID: 23223 - Kerri Milarch ( 2517 ) - coders: [1][2]:  ==> [1] - coder=9; detected=1; person=2517 ==> [2] - coder=9; detected=1; person=2517
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - source: 13974 - label: prelim_month_human - article ID: 23223 - Satan ( 2518 ) - coders: [1][2]:  ==> [1] - coder=9; detected=1; person=2518 ==> [2] - coder=9; detected=1; person=2518
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - author: 13975 - label: prelim_month_human - article ID: 23631 - Steve Ungrey ( 703 ) - coders: [1][2]:  ==> [1] - coder=10; detected=1; person=703 ==> [2] - coder=10; detected=1; person=703
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - source: 13976 - label: prelim_month_human - article ID: 23631 - Kevin Henry ( 2688 ) - coders: [1][2]:  ==> [1] - coder=10; detected=1; person=2688 ==> [2] - coder=10; detected=1; person=2688
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - source: 13977 - label: prelim_month_human - article ID: 23631 - Bryant Slaughter ( 2689 ) - coders: [1][2]:  ==> [1] - coder=10; detected=1; person=2689 ==> [2] - coder=10; detected=1; person=2689
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - source: 13978 - label: prelim_month_human - article ID: 23631 - Nathan Cox ( 2690 ) - coders: [1][2]:  ==> [1] - coder=10; detected=1; person=2690 ==> [2] - coder=10; detected=1; person=2690
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - source: 13979 - label: prelim_month_human - article ID: 23631 - Lorenzo Ecford ( 2691 ) - coders: [1][2]:  ==> [1] - coder=10; detected=1; person=2691 ==> [2] - coder=10; detected=1; person=2691
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - source: 13980 - label: prelim_month_human - article ID: 23631 - Glenn Van Wieren ( 1808 ) - coders: [1][2]:  ==> [1] - coder=10; detected=1; person=1808 ==> [2] - coder=10; detected=1; person=1808
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - source: 13981 - label: prelim_month_human - article ID: 23631 - Russ DeVette ( 2687 ) - coders: [1][2]:  ==> [1] - coder=10; detected=1; person=2687 ==> [2] - coder=10; detected=1; person=2687
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - author: 13982 - label: prelim_month_human - article ID: 22608 - Julia Bauer ( 443 ) - coders: [1][2]:  ==> [1] - coder=13; detected=1; person=443 ==> [2] - coder=10; detected=1; person=443
# ----> In output_reliability_name_row: len( index_used_list ) = 1; list = [2]
# - source: 13983 - label: prelim_month_human - article ID: 22608 - Herman Miller ( 1792 ) - coders: [1][2]:  ==> [1] - coder=13; detected=0; person=0 ==> [2] - coder=10; detected=1; person=1792
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - source: 13984 - label: prelim_month_human - article ID: 22608 - Brian Walker ( 633 ) - coders: [1][2]:  ==> [1] - coder=13; detected=1; person=633 ==> [2] - coder=10; detected=1; person=633
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - author: 13985 - label: prelim_month_human - article ID: 21588 - Myron Kukla ( 599 ) - coders: [1][2]:  ==> [1] - coder=13; detected=1; person=599 ==> [2] - coder=8; detected=1; person=599
# ----> In output_reliability_name_row: len( index_used_list ) = 1; list = [2]
# - source: 13986 - label: prelim_month_human - article ID: 21588 - Herman Miller ( 1792 ) - coders: [1][2]:  ==> [1] - coder=13; detected=0; person=0 ==> [2] - coder=8; detected=1; person=1792
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - source: 13987 - label: prelim_month_human - article ID: 21588 - Mark Tanis ( 528 ) - coders: [1][2]:  ==> [1] - coder=13; detected=1; person=528 ==> [2] - coder=8; detected=1; person=528
# ----> In output_reliability_name_row: len( index_used_list ) = 1; list = [1]
# - source: 13988 - label: prelim_month_human - article ID: 21588 - Charles Eames ( 895 ) - coders: [1][2]:  ==> [1] - coder=13; detected=1; person=895 ==> [2] - coder=8; detected=0; person=0
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - source: 13989 - label: prelim_month_human - article ID: 21588 - Brian Walker ( 633 ) - coders: [1][2]:  ==> [1] - coder=13; detected=1; person=633 ==> [2] - coder=8; detected=1; person=633
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - source: 13990 - label: prelim_month_human - article ID: 21588 - Ray Eames ( 890 ) - coders: [1][2]:  ==> [1] - coder=13; detected=1; person=890 ==> [2] - coder=8; detected=1; person=890
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - source: 13991 - label: prelim_month_human - article ID: 21588 - David Slikkers ( 891 ) - coders: [1][2]:  ==> [1] - coder=13; detected=1; person=891 ==> [2] - coder=8; detected=1; person=891
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - source: 13992 - label: prelim_month_human - article ID: 21588 - John Berry ( 892 ) - coders: [1][2]:  ==> [1] - coder=13; detected=1; person=892 ==> [2] - coder=8; detected=1; person=892
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - source: 13993 - label: prelim_month_human - article ID: 21588 - Kevin Budelmann ( 893 ) - coders: [1][2]:  ==> [1] - coder=13; detected=1; person=893 ==> [2] - coder=8; detected=1; person=893
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - source: 13994 - label: prelim_month_human - article ID: 21588 - Chuck Jones ( 894 ) - coders: [1][2]:  ==> [1] - coder=13; detected=1; person=894 ==> [2] - coder=8; detected=1; person=894
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - source: 13995 - label: prelim_month_human - article ID: 21588 - Nate Young ( 527 ) - coders: [1][2]:  ==> [1] - coder=13; detected=1; person=527 ==> [2] - coder=8; detected=1; person=527
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - author: 13996 - label: prelim_month_human - article ID: 21590 - Morgan Jarema ( 505 ) - coders: [1][2]:  ==> [1] - coder=10; detected=1; person=505 ==> [2] - coder=10; detected=1; person=505
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - source: 13997 - label: prelim_month_human - article ID: 21590 - Stephen Doyle ( 506 ) - coders: [1][2]:  ==> [1] - coder=10; detected=1; person=506 ==> [2] - coder=10; detected=1; person=506
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - source: 13998 - label: prelim_month_human - article ID: 21590 - Parry Beachum ( 507 ) - coders: [1][2]:  ==> [1] - coder=10; detected=1; person=507 ==> [2] - coder=10; detected=1; person=507
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - source: 13999 - label: prelim_month_human - article ID: 21590 - Eric Schelhaas ( 508 ) - coders: [1][2]:  ==> [1] - coder=10; detected=1; person=508 ==> [2] - coder=10; detected=1; person=508
# ...
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - source: 16195 - label: prelim_month_human - article ID: 21863 - Bob Patel ( 976 ) - coders: [1][2]:  ==> [1] - coder=13; detected=1; person=976 ==> [2] - coder=8; detected=1; person=976
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - source: 16196 - label: prelim_month_human - article ID: 21863 - Dwight Fausnaugh ( 448 ) - coders: [1][2]:  ==> [1] - coder=13; detected=1; person=448 ==> [2] - coder=8; detected=1; person=448
# ----> In output_reliability_name_row: len( index_used_list ) = 1; list = [1]
# - source: 16197 - label: prelim_month_human - article ID: 21863 - Kelly Keith ( 977 ) - coders: [1][2]:  ==> [1] - coder=13; detected=1; person=977 ==> [2] - coder=8; detected=0; person=0
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - author: 16198 - label: prelim_month_human - article ID: 23529 - John Tunison ( 84 ) - coders: [1][2]:  ==> [1] - coder=10; detected=1; person=84 ==> [2] - coder=10; detected=1; person=84
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - source: 16199 - label: prelim_month_human - article ID: 23529 - DeDe Stancell ( 2673 ) - coders: [1][2]:  ==> [1] - coder=10; detected=1; person=2673 ==> [2] - coder=10; detected=1; person=2673
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - source: 16200 - label: prelim_month_human - article ID: 23529 - Gary Stancell ( 2674 ) - coders: [1][2]:  ==> [1] - coder=10; detected=1; person=2674 ==> [2] - coder=10; detected=1; person=2674
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - source: 16201 - label: prelim_month_human - article ID: 23529 - Betsy VanKlompenberg ( 2675 ) - coders: [1][2]:  ==> [1] - coder=10; detected=1; person=2675 ==> [2] - coder=10; detected=1; person=2675
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - source: 16202 - label: prelim_month_human - article ID: 23529 - Keith VanKlompenberg ( 2676 ) - coders: [1][2]:  ==> [1] - coder=10; detected=1; person=2676 ==> [2] - coder=10; detected=1; person=2676
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - source: 16203 - label: prelim_month_human - article ID: 23529 - Rena Guttrich ( 2677 ) - coders: [1][2]:  ==> [1] - coder=10; detected=1; person=2677 ==> [2] - coder=10; detected=1; person=2677
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - source: 16204 - label: prelim_month_human - article ID: 23529 - Bruce Guttrich ( 2678 ) - coders: [1][2]:  ==> [1] - coder=10; detected=1; person=2678 ==> [2] - coder=10; detected=1; person=2678
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - author: 16205 - label: prelim_month_human - article ID: 21483 - Julie Makarewicz ( 30 ) - coders: [1][2]:  ==> [1] - coder=8; detected=1; person=30 ==> [2] - coder=8; detected=1; person=30
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - source: 16206 - label: prelim_month_human - article ID: 21483 - Mike Miles ( 176 ) - coders: [1][2]:  ==> [1] - coder=8; detected=1; person=176 ==> [2] - coder=8; detected=1; person=176
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - source: 16207 - label: prelim_month_human - article ID: 21483 - Richard Root ( 32 ) - coders: [1][2]:  ==> [1] - coder=8; detected=1; person=32 ==> [2] - coder=8; detected=1; person=32
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - source: 16208 - label: prelim_month_human - article ID: 21483 - Sharon Brinks ( 750 ) - coders: [1][2]:  ==> [1] - coder=8; detected=1; person=750 ==> [2] - coder=8; detected=1; person=750
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - source: 16209 - label: prelim_month_human - article ID: 21483 - Gladys Verhulst ( 172 ) - coders: [1][2]:  ==> [1] - coder=8; detected=1; person=172 ==> [2] - coder=8; detected=1; person=172
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - source: 16210 - label: prelim_month_human - article ID: 21483 - Roger Brouwer ( 173 ) - coders: [1][2]:  ==> [1] - coder=8; detected=1; person=173 ==> [2] - coder=8; detected=1; person=173
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - source: 16211 - label: prelim_month_human - article ID: 21483 - John Pellerito ( 174 ) - coders: [1][2]:  ==> [1] - coder=8; detected=1; person=174 ==> [2] - coder=8; detected=1; person=174
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - source: 16212 - label: prelim_month_human - article ID: 21483 - Albert Kuperus ( 175 ) - coders: [1][2]:  ==> [1] - coder=8; detected=1; person=175 ==> [2] - coder=8; detected=1; person=175
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - author: 16213 - label: prelim_month_human - article ID: 23532 - Julia Bauer ( 443 ) - coders: [1][2]:  ==> [1] - coder=9; detected=1; person=443 ==> [2] - coder=9; detected=1; person=443
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - source: 16214 - label: prelim_month_human - article ID: 23532 - Matt Becker ( 2560 ) - coders: [1][2]:  ==> [1] - coder=9; detected=1; person=2560 ==> [2] - coder=9; detected=1; person=2560
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - source: 16215 - label: prelim_month_human - article ID: 23532 - Bill Seidman ( 2559 ) - coders: [1][2]:  ==> [1] - coder=9; detected=1; person=2559 ==> [2] - coder=9; detected=1; person=2559
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - author: 16216 - label: prelim_month_human - article ID: 21890 - Matt VandeBunte ( 591 ) - coders: [1][2]:  ==> [1] - coder=8; detected=1; person=591 ==> [2] - coder=8; detected=1; person=591
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - source: 16217 - label: prelim_month_human - article ID: 21890 - Michael Schadick ( 312 ) - coders: [1][2]:  ==> [1] - coder=8; detected=1; person=312 ==> [2] - coder=8; detected=1; person=312
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - source: 16218 - label: prelim_month_human - article ID: 21890 - Karen Libman ( 310 ) - coders: [1][2]:  ==> [1] - coder=8; detected=1; person=310 ==> [2] - coder=8; detected=1; person=310
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - source: 16219 - label: prelim_month_human - article ID: 21890 - Mark Binder ( 311 ) - coders: [1][2]:  ==> [1] - coder=8; detected=1; person=311 ==> [2] - coder=8; detected=1; person=311
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - author: 16220 - label: prelim_month_human - article ID: 22512 - Julia Bauer ( 443 ) - coders: [1][2]:  ==> [1] - coder=8; detected=1; person=443 ==> [2] - coder=8; detected=1; person=443
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - source: 16221 - label: prelim_month_human - article ID: 22512 - Brian Walker ( 633 ) - coders: [1][2]:  ==> [1] - coder=8; detected=1; person=633 ==> [2] - coder=8; detected=1; person=633
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - author: 16222 - label: prelim_month_human - article ID: 22879 - Nate Reens ( 46 ) - coders: [1][2]:  ==> [1] - coder=8; detected=1; person=46 ==> [2] - coder=8; detected=1; person=46
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - source: 16223 - label: prelim_month_human - article ID: 22879 - Ralph Mason ( 2027 ) - coders: [1][2]:  ==> [1] - coder=8; detected=1; person=2027 ==> [2] - coder=8; detected=1; person=2027
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - source: 16224 - label: prelim_month_human - article ID: 22879 - Caitlynn Butterfield ( 2068 ) - coders: [1][2]:  ==> [1] - coder=8; detected=1; person=2068 ==> [2] - coder=8; detected=1; person=2068
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - source: 16225 - label: prelim_month_human - article ID: 22879 - Walter Gort ( 2069 ) - coders: [1][2]:  ==> [1] - coder=8; detected=1; person=2069 ==> [2] - coder=8; detected=1; person=2069
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - source: 16226 - label: prelim_month_human - article ID: 22879 - Jeremy Wheeler ( 2070 ) - coders: [1][2]:  ==> [1] - coder=8; detected=1; person=2070 ==> [2] - coder=8; detected=1; person=2070
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - source: 16227 - label: prelim_month_human - article ID: 22879 - Rebecca Wheeler ( 2071 ) - coders: [1][2]:  ==> [1] - coder=8; detected=1; person=2071 ==> [2] - coder=8; detected=1; person=2071
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - source: 16228 - label: prelim_month_human - article ID: 22879 - Alysia Bolks ( 2072 ) - coders: [1][2]:  ==> [1] - coder=8; detected=1; person=2072 ==> [2] - coder=8; detected=1; person=2072
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - source: 16229 - label: prelim_month_human - article ID: 22879 - Anna Bolks ( 2073 ) - coders: [1][2]:  ==> [1] - coder=8; detected=1; person=2073 ==> [2] - coder=8; detected=1; person=2073
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - source: 16230 - label: prelim_month_human - article ID: 22879 - Zoey Bolks ( 2074 ) - coders: [1][2]:  ==> [1] - coder=8; detected=1; person=2074 ==> [2] - coder=8; detected=1; person=2074
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - source: 16231 - label: prelim_month_human - article ID: 22879 - Todd Hall ( 2075 ) - coders: [1][2]:  ==> [1] - coder=8; detected=1; person=2075 ==> [2] - coder=8; detected=1; person=2075
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - author: 16232 - label: prelim_month_human - article ID: 23379 - Aaron Ogg ( 425 ) - coders: [1][2]:  ==> [1] - coder=8; detected=1; person=425 ==> [2] - coder=8; detected=1; person=425
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - source: 16233 - label: prelim_month_human - article ID: 23379 - Howard Mosley ( 2149 ) - coders: [1][2]:  ==> [1] - coder=8; detected=1; person=2149 ==> [2] - coder=8; detected=1; person=2149
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - source: 16234 - label: prelim_month_human - article ID: 23379 - Jeff Truszkowski ( 2150 ) - coders: [1][2]:  ==> [1] - coder=8; detected=1; person=2150 ==> [2] - coder=8; detected=1; person=2150
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - source: 16235 - label: prelim_month_human - article ID: 23379 - Juanita Davis ( 2151 ) - coders: [1][2]:  ==> [1] - coder=8; detected=1; person=2151 ==> [2] - coder=8; detected=1; person=2151
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - source: 16236 - label: prelim_month_human - article ID: 23379 - Lisa Brouwer ( 2152 ) - coders: [1][2]:  ==> [1] - coder=8; detected=1; person=2152 ==> [2] - coder=8; detected=1; person=2152
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - source: 16237 - label: prelim_month_human - article ID: 23379 - Barrie Bechtel ( 2153 ) - coders: [1][2]:  ==> [1] - coder=8; detected=1; person=2153 ==> [2] - coder=8; detected=1; person=2153
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - source: 16238 - label: prelim_month_human - article ID: 23379 - Leah Weis ( 2154 ) - coders: [1][2]:  ==> [1] - coder=8; detected=1; person=2154 ==> [2] - coder=8; detected=1; person=2154
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - author: 16239 - label: prelim_month_human - article ID: 21495 - Susie Fair ( 387 ) - coders: [1][2]:  ==> [1] - coder=10; detected=1; person=387 ==> [2] - coder=10; detected=1; person=387
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - source: 16240 - label: prelim_month_human - article ID: 21495 - Merrill Russell ( 388 ) - coders: [1][2]:  ==> [1] - coder=10; detected=1; person=388 ==> [2] - coder=10; detected=1; person=388
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - source: 16241 - label: prelim_month_human - article ID: 21495 - Jani Millard ( 389 ) - coders: [1][2]:  ==> [1] - coder=10; detected=1; person=389 ==> [2] - coder=10; detected=1; person=389
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - source: 16242 - label: prelim_month_human - article ID: 21495 - George Dressander ( 390 ) - coders: [1][2]:  ==> [1] - coder=10; detected=1; person=390 ==> [2] - coder=10; detected=1; person=390
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - source: 16243 - label: prelim_month_human - article ID: 21495 - Larry Rummel ( 391 ) - coders: [1][2]:  ==> [1] - coder=10; detected=1; person=391 ==> [2] - coder=10; detected=1; person=391
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - author: 16244 - label: prelim_month_human - article ID: 22523 - Brian McVicar ( 66 ) - coders: [1][2]:  ==> [1] - coder=9; detected=1; person=66 ==> [2] - coder=9; detected=1; person=66
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - source: 16245 - label: prelim_month_human - article ID: 22523 - Layla Millbrooks ( 2373 ) - coders: [1][2]:  ==> [1] - coder=9; detected=1; person=2373 ==> [2] - coder=9; detected=1; person=2373
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - source: 16246 - label: prelim_month_human - article ID: 22523 - Rebecca Cajka ( 2374 ) - coders: [1][2]:  ==> [1] - coder=9; detected=1; person=2374 ==> [2] - coder=9; detected=1; person=2374
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - source: 16247 - label: prelim_month_human - article ID: 22523 - Janice Wilson ( 2375 ) - coders: [1][2]:  ==> [1] - coder=9; detected=1; person=2375 ==> [2] - coder=9; detected=1; person=2375
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - author: 16248 - label: prelim_month_human - article ID: 21501 - Matt VandeBunte ( 591 ) - coders: [1][2]:  ==> [1] - coder=9; detected=1; person=591 ==> [2] - coder=9; detected=1; person=591
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - source: 16249 - label: prelim_month_human - article ID: 21501 - Ron Caniff ( 404 ) - coders: [1][2]:  ==> [1] - coder=9; detected=1; person=404 ==> [2] - coder=9; detected=1; person=404
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - source: 16250 - label: prelim_month_human - article ID: 21501 - Arelis Diaz ( 402 ) - coders: [1][2]:  ==> [1] - coder=9; detected=1; person=402 ==> [2] - coder=9; detected=1; person=402
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - source: 16251 - label: prelim_month_human - article ID: 21501 - Allen E. Johnston ( 187 ) - coders: [1][2]:  ==> [1] - coder=9; detected=1; person=187 ==> [2] - coder=9; detected=1; person=187
# ----> In output_reliability_name_row: len( index_used_list ) = 2; list = [1, 2]
# - source: 16252 - label: prelim_month_human - article ID: 21501 - Gerald Hopkins ( 403 ) - coders: [1][2]:  ==> [1] - coder=9; detected=1; person=403 ==> [2] - coder=9; detected=1; person=403
# reliability data created at 2017-10-26 03:52:17.132922

# %% [markdown]
#     SELECT COUNT( * )
#     FROM sourcenet_analysis_reliability_names
#     WHERE label = 'prelim_month';
#
#     -- 2446
#
#     SELECT COUNT( * )
#     FROM sourcenet_analysis_reliability_names
#     WHERE label = 'prelim_month_human';
#
#     -- 2429

# %% [markdown]
# # Database backup - `sourcenet-2017.10.20.pg.sql.gz`
#
# - Back to [Table of Contents](#Table-of-Contents)
#
# First, making backup of database.
#
# - File name: `sourcenet-2017.10.20.pg.sql.gz`
# - command (logged in as postgres user):
#
#         pg_dump -O -c --if-exists -C sourcenet | gzip -c > sourcenet-2017.10.20.pg.sql.gz
#
# - All articles in tag "grp_month" are coded by OpenCalais.
# - Reliability data generated with label "prelim_month" and single name cleanup and disagreement evaluation completed.
# - Reliability data generated with label "prelim_month_human", no cleanup completed yet.

# %% [markdown]
# # Data cleanup
#
# - Back to [Table of Contents](#Table-of-Contents)

# %% [markdown]
# ## Remove single-name reliability data
#
# - Back to [Table of Contents](#Table-of-Contents)
#
# Next, remove all reliability data that refers to a single name using the "View reliability name information" screen:
#
# - [https://research.local/sourcenet/sourcenet/analysis/reliability/names/disagreement/view](https://research.local/sourcenet/sourcenet/analysis/reliability/names/disagreement/view)
#
# To start, enter the following in fields there:
#
# - Label: - "prelim_month_human"
# - Coders to compare (1 through ==>): - 2
# - Reliability names filter type: - Select "Lookup"
# - [Lookup] - Person has first name, no other name parts. - CHECK the checkbox
#
# You should see entries where a coder detected people who were mentioned only by their first name.
#
# For each:

# %% [markdown]
# ### Single-name data assessment
#
# - Back to [Table of Contents](#Table-of-Contents)
#
# Need to look at each instance where a person has a single name part.
#
# Most are probably instances where the computer correctly detected the name part, but where you don't have enough name to match it to a person so the human coding protocol directed them to not capture the name fragment.
#
# However, there might be some where a coder made a mistake and just captured a name part for a person whose full name was in the story.  To check, click the "Article ID" in the column that has a link to article ID. It will take you to a view of the article where all the people who coded the article are included, with each detection of a mention or quotation displayed next to the paragraph where the person was originally first detected.
#
# So for each instance of a single name part:
#
# - click on the article ID link in the row to go to the article and check to see if there is person whose name the fragment is a part of ( [https://research.local/sourcenet/sourcenet/article/article_data/view_with_text/](https://research.local/sourcenet/sourcenet/article/article_data/view_with_text/) ).
#
#     - If there is a person with a full name to which the name fragment is a reference, check to see if the coder has data for the full person.
#
#         - if not, merge:
#
#             - go to the disagreement view page: [https://research.local/sourcenet/sourcenet/analysis/reliability/names/disagreement/view](https://research.local/sourcenet/sourcenet/analysis/reliability/names/disagreement/view)
#             - Configure:
#
#                 - Label: - "prelim_month"
#                 - Coders to compare (1 through ==>): - 2
#                 - Reliability names filter type: - Select "Lookup"
#                 - [Lookup] - Associated Article IDs (comma-delimited): - Enter the ID of the article the coding belonged to.
#
#             - this will bring up all coding for the article whose ID you entered.
#             - In the "select" column, click the checkbox in the row where there is a single name part that needs to be merged.
#             - In the "merge INTO" column, click the checbox in the row with the full name for that person.
#             - In "Reliability Names Action", choose "Merge Coding --> FROM 1 SELECTED / INTO 1"
#             - Click "Do Action" button.
#
#     - Remove the `Reliability_Names` row with the name fragment from reliability data.
#
#         - In the "select" column, click the checkbox in the row where there is a single name part that needs to be removed.
#         - In "Reliability Names Action", choose "Delete selected".
#         - Click "Do Action" button.

# %% [markdown]
# ### Delete selected single-name data
#
# - Back to [Table of Contents](#Table-of-Contents)
#
# To see the 8 single-name instances that were addressed: [https://research.local/sourcenet/admin/sourcenet_analysis/reliability_names_evaluation/?label=prelim_month_human](https://research.local/sourcenet/admin/sourcenet_analysis/reliability_names_evaluation/?label=prelim_month_human)

# %% [markdown]
# # Calculate precision and recall
#
# - Back to [Table of Contents](#Table-of-Contents)
#
# Now, we use the code we created for assessing OpenCalais to calculate precision and recall of human coders compared to ground truth (corrected human coders).
#
# - [https://research.local:8000/user/jonathanmorgan/notebooks/work/sourcenet/django/research/work/msu_phd_work/2017.10.21-work_log-prelim_month_human-confusion_matrix.ipynb](https://research.local:8000/user/jonathanmorgan/notebooks/work/sourcenet/django/research/work/msu_phd_work/2017.10.21-work_log-prelim_month_human-confusion_matrix.ipynb)

# %% [markdown]
# # TODO
#
# - Back to [Table of Contents](#Table-of-Contents)
#
# TODO:
#
# - write unit tests for IndexHelper, IndexInfo, and CoderIndexInfo.
# - update reliability_names_builder to use IndexHelper.
