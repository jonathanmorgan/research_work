# %% [markdown]
# **R statnet - grp month - compare graphs**
#
# _2017.12.02 - work log - prelim - R - statnet - grp month_

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#R-network-analysis-files" data-toc-modified-id="R-network-analysis-files-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>R network analysis files</a></span></li><li><span><a href="#Setup" data-toc-modified-id="Setup-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Setup</a></span><ul class="toc-item"><li><span><a href="#Setup----working-directories" data-toc-modified-id="Setup----working-directories-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Setup -  working directories</a></span></li><li><span><a href="#Setup---import-SNA-functions" data-toc-modified-id="Setup---import-SNA-functions-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Setup - import SNA functions</a></span></li><li><span><a href="#Setup---network-data---render-and-store-network-data" data-toc-modified-id="Setup---network-data---render-and-store-network-data-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Setup - network data - render and store network data</a></span><ul class="toc-item"><li><span><a href="#data---grp_month" data-toc-modified-id="data---grp_month-2.3.1"><span class="toc-item-num">2.3.1&nbsp;&nbsp;</span>data - grp_month</a></span></li></ul></li><li><span><a href="#Setup---load-workspace" data-toc-modified-id="Setup---load-workspace-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Setup - load workspace</a></span></li></ul></li><li><span><a href="#Compare-grp_week_1-and-grp_week_2-using-QAP" data-toc-modified-id="Compare-grp_week_1-and-grp_week_2-using-QAP-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Compare <code>grp_week_1</code> and <code>grp_week_2</code> using QAP</a></span><ul class="toc-item"><li><span><a href="#week_1-to-week_2---automated" data-toc-modified-id="week_1-to-week_2---automated-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>week_1-to-week_2 - automated</a></span></li><li><span><a href="#week_1-to-week_2---human" data-toc-modified-id="week_1-to-week_2---human-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>week_1-to-week_2 - human</a></span></li></ul></li><li><span><a href="#Compare-grp_week_1-and-grp_week_3-using-QAP" data-toc-modified-id="Compare-grp_week_1-and-grp_week_3-using-QAP-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Compare <code>grp_week_1</code> and <code>grp_week_3</code> using QAP</a></span><ul class="toc-item"><li><span><a href="#week_1-to-week_3---automated" data-toc-modified-id="week_1-to-week_3---automated-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>week_1-to-week_3 - automated</a></span></li><li><span><a href="#week_1-to-week_3---human" data-toc-modified-id="week_1-to-week_3---human-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>week_1-to-week_3 - human</a></span></li></ul></li><li><span><a href="#Compare-grp_week_2-and-grp_week_3-using-QAP" data-toc-modified-id="Compare-grp_week_2-and-grp_week_3-using-QAP-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Compare <code>grp_week_2</code> and <code>grp_week_3</code> using QAP</a></span><ul class="toc-item"><li><span><a href="#week_2-to-week_3---automated" data-toc-modified-id="week_2-to-week_3---automated-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>week_2-to-week_3 - automated</a></span></li><li><span><a href="#week_2-to-week_3---human" data-toc-modified-id="week_2-to-week_3---human-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>week_2-to-week_3 - human</a></span></li></ul></li><li><span><a href="#Compare-grp_month-and-grp_week_1-using-QAP" data-toc-modified-id="Compare-grp_month-and-grp_week_1-using-QAP-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Compare <code>grp_month</code> and <code>grp_week_1</code> using QAP</a></span><ul class="toc-item"><li><span><a href="#month-to-week_1---automated" data-toc-modified-id="month-to-week_1---automated-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>month-to-week_1 - automated</a></span></li><li><span><a href="#month-to-week_1---human" data-toc-modified-id="month-to-week_1---human-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>month-to-week_1 - human</a></span></li></ul></li><li><span><a href="#Compare-grp_month-and-grp_week_2-using-QAP" data-toc-modified-id="Compare-grp_month-and-grp_week_2-using-QAP-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Compare <code>grp_month</code> and <code>grp_week_2</code> using QAP</a></span><ul class="toc-item"><li><span><a href="#month-to-week_2---automated" data-toc-modified-id="month-to-week_2---automated-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>month-to-week_2 - automated</a></span></li><li><span><a href="#month-to-week_2---human" data-toc-modified-id="month-to-week_2---human-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>month-to-week_2 - human</a></span></li></ul></li><li><span><a href="#Compare-grp_month-and-grp_week_3-using-QAP" data-toc-modified-id="Compare-grp_month-and-grp_week_3-using-QAP-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Compare <code>grp_month</code> and <code>grp_week_3</code> using QAP</a></span><ul class="toc-item"><li><span><a href="#month-to-week_3---automated" data-toc-modified-id="month-to-week_3---automated-8.1"><span class="toc-item-num">8.1&nbsp;&nbsp;</span>month-to-week_3 - automated</a></span></li><li><span><a href="#month-to-week_3---human" data-toc-modified-id="month-to-week_3---human-8.2"><span class="toc-item-num">8.2&nbsp;&nbsp;</span>month-to-week_3 - human</a></span></li></ul></li><li><span><a href="#Save-workspace-image" data-toc-modified-id="Save-workspace-image-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Save workspace image</a></span></li></ul></div>

# %% [markdown]
# # R network analysis files
#
# - Back to [Table of Contents](#Table-of-Contents)
#
# Related files:
#
# * network descriptives
#     * network-level
#
#         * files
#
#             * R scripts:
#
#                 * `sourcenet/R/db_connect.r`
#                 * `sourcenet/R/sna/functions-sna.r`
#                 * `sourcenet/R/sna/sna-load_data.r`
#                 * `sourcenet/R/sna/igraph/*`
#                 * `sourcenet/R/sna/statnet/*`
#
#         * statnet/sna
#
#             * `sna::gden()` - graph density
#             * R scripts:
#
#                 * `sourcenet/R/sna/statnet/sna-statnet-init.r`
#                 * `sourcenet/R/sna/statnet/sna-statnet-network-stats.r`
#                 * `sourcenet/R/sna/statnet/sna-qap.r`
#
#         * igraph
#
#             * `igraph::transitivity()` - vector of transitivity scores for each node in a graph, plus network-level transitivity score.
#
#                 * Q - interpretation?
#
#             * R scripts:
#
#                 * `sourcenet/R/sna/statnet/sna-igraph-init.r`
#                 * `sourcenet/R/sna/statnet/sna-igraph-network-stats.r`

# %% [markdown]
# # Setup
#
# - Back to [Table of Contents](#Table-of-Contents)

# %% [markdown]
# ## Setup -  working directories
#
# - Back to [Table of Contents](#Table-of-Contents)
#
# Store important directories and file names in variables:

# %%
getwd()
# Out:
# [1] "/home/jonathanmorgan/work/django/research/work/phd_work/methods/network_analysis/statnet"

# %%
# code files (in particular SNA function library, modest though it may be)
code_directory <- "/home/jonathanmorgan/work/django/research/context_analysis/R/sna"
sna_function_file_path <- paste( code_directory, "/", 'functions-sna.r', sep = "" )

# home directory
home_directory <- getwd()
home_directory <- "/home/jonathanmorgan/work/django/research/work/phd_work/methods"

# data directories
data_directory <- paste( home_directory, "/data", sep = "" )
workspace_file_name <- "statnet-grp_month.RData"
workspace_file_path <- paste( data_directory, "/", workspace_file_name )

# %%
# set working directory to data directory for now.
setwd( data_directory )
getwd()
# Out:
# [1] "/home/jonathanmorgan/work/django/research/work/phd_work/methods/data"

# %% [markdown]
# ## Setup - import SNA functions
#
# - Back to [Table of Contents](#Table-of-Contents)
#
# source the file `functions-sna.r`.

# %%
source( sna_function_file_path )

# %% [markdown]
# ## Setup - network data - render and store network data
#
# - Back to [Table of Contents](#Table-of-Contents)
#
# First, need render to render network data and upload it to your server.
#
# Directions for rendering network data are in [2017.11.14-work_log-prelim-network_analysis.ipynb](2017.11.14-work_log-prelim-network_analysis.ipynb).  You want a tab-delimited matrix that includes both the network and attributes of nodes as columns, and you want it to include a header row.
#
# Once you render your network data files, you should place them on the server.
#
# High level data file layout:
#
# - tab-delimited.
# - first row and first column are labels
# - last 2 columns are traits of nodes (`person_id` and `person_type`)
# - each row and column after first until the trait columns represents a person found in one of the articles.
# - The people are in the same order from top to bottom and left to right.
# - Where the row and column of two people meet, and one of the people is an author, the nunber in the cell where they meet is the number of times the non-author was quoted in an article by the author.  Does not include more basic two-mode co-location ties (appeared in same article, even if not an author and/or not quoted).
#
# Files and their location on server:

# %% [markdown]
# ### data - grp_month
#
# - Back to [Table of Contents](#Table-of-Contents)
#
# This is data from the Grand Rapids Press articles from December of 2009, coded by both humans and OpenCalais.
#
# Files:
#
# - automated full month - `sourcenet_data-20171205-022551-grp_month-automated.tab`
# - human full month - `sourcenet_data-20171115-043102-grp_month-human.tab`
# - automated week 1 subset - `sourcenet_data-20171206-031358-grp_month-automated-week1_subset.tab`
# - human week 1 subset - `sourcenet_data-20171206-031319-grp_month-human-week1_subset.tab`
# - automated week 2 subset - `sourcenet_data-20180326-040445-grp_month-automated-week2_subset.tab`
# - human week 2 subset - `sourcenet_data-20180326-034401-grp_month-human-week2_subset.tab`
# - automated week 3 subset - `sourcenet_data-20180326-040736-grp_month-automated-week3_subset.tab`
# - human week 3 subset - `sourcenet_data-20180326-034548-grp_month-human-week3_subset.tab`
#
# Location in Dropbox: `Dropbox/academia/MSU/program_stuff/prelim_paper/data/network_analysis/2017.11.14/network/new_coders/grp_month`
#
# Location on server: `/home/jonathanmorgan/work/django/research/work/phd_work/data/network/grp_month`

# %% [markdown]
# ## Setup - load workspace
#
# - Back to [Table of Contents](#Table-of-Contents)
#
# You must load this file's workspace, from a previous run:

# %%
# assumes that you've already set working directory above to the
#     working directory.
setwd( data_directory )
load( workspace_file_name )

# %% [markdown]
# # Compare `grp_week_1` and `grp_week_2` using QAP
#
# - Back to [Table of Contents](#Table-of-Contents)
#
# Now, compare the automated and human-coded networks from a week 1 and week 2 to each other, to look at similarity of weeks over time (I'd expect it to be small).
#
# Based on: `sourcenet/R/sna/statnet/sna-qap.r`

# %% [markdown]
# ## week_1-to-week_2 - automated
#
# - Back to [Table of Contents](#Table-of-Contents)

# %%
output_prefix <- "week_1-to-week_2 automated"

# %%
# link to good doc on qaptest(){sna} function: http://www.inside-r.org/packages/cran/sna/docs/qaptest

# First, need to load data - see (or just source() ) the file "sna-load_data.r".
# source( "sna-load_data.r" )
# does the following (among other things):
# Start with loading in tab-delimited files.
#humanNetworkData <- read.delim( "human-sourcenet_data-20150504-002453.tab", header = TRUE, row.names = 1, check.names = FALSE )
#calaisNetworkData <- read.delim( "puter-sourcenet_data-20150504-002507.tab", header = TRUE, row.names = 1, check.names = FALSE )

# remove the right-most column, which contains non-tie info on nodes.
#humanNetworkTies <- humanNetworkData[ , -ncol( humanNetworkData ) ]
#gw2AutomatedNetworkDF <- calaisNetworkData[ , -ncol( calaisNetworkData )]

# convert each to a matrix
#gw2HumanNetworkMatrix <- as.matrix( gw2HumanNetworkTies )
#gw2AutomatedNetworkMatrix <- as.matrix( gw2AutomatedNetworkDF )

# imports
# install.packages( "sna" )
# install.packages( "statnet" )
library( "sna" )

# package up data for calling qaptest() - first make 3-dimensional array to hold
#    our two matrices - this is known as a "graph set".
graphSetArray <- array( dim = c( 2, ncol( gw1AutomatedNetworkMatrix ), nrow( gw1AutomatedNetworkMatrix ) ) )

# then, place each matrix in one dimension of the array.
graphSetArray[ 1, , ] <- gw1AutomatedNetworkMatrix
graphSetArray[ 2, , ] <- gw2AutomatedNetworkMatrix

# first, try a graph correlation
graphCorrelation <- sna::gcor( gw1AutomatedNetworkMatrix, gw2AutomatedNetworkMatrix )
paste( output_prefix, "graph correlation =", graphCorrelation, sep = " " )

# try a qaptest...
qapGcorResult <- sna::qaptest( graphSetArray, sna::gcor, g1 = 1, g2 = 2 )
summary( qapGcorResult )
plot( qapGcorResult )

# graph covariance...
graphCovariance <- sna::gcov( gw1AutomatedNetworkMatrix, gw2AutomatedNetworkMatrix )
graphCovariance
paste( output_prefix, "graph covariance =", graphCovariance, sep = " " )

# try a qaptest...
qapGcovResult <- sna::qaptest( graphSetArray, sna::gcov, g1 = 1, g2 = 2 )
summary( qapGcovResult )
plot( qapGcovResult )

# Hamming Distance
graphHammingDist <- sna::hdist( gw1AutomatedNetworkMatrix, gw2AutomatedNetworkMatrix )
paste( output_prefix, "graph hamming distance =", graphHammingDist, sep = " " )

# try a qaptest...
qapHdistResult <- sna::qaptest( graphSetArray, sna::hdist, g1 = 1, g2 = 2 )
summary( qapHdistResult )
plot( qapHdistResult )

# graph structural correlation?
#graphStructCorrelation <- gscor( gw2HumanNetworkMatrix, gw2AutomatedNetworkMatrix )
#graphStructCorrelation
# Out:
# Loading required package: statnet.common
#
# Attaching package: ‘statnet.common’
#
# The following object is masked from ‘package:base’:
#
#     order
#
# Loading required package: network
# network: Classes for Relational Data
# Version 1.13.0 created on 2015-08-31.
# copyright (c) 2005, Carter T. Butts, University of California-Irvine
#                     Mark S. Handcock, University of California -- Los Angeles
#                     David R. Hunter, Penn State University
#                     Martina Morris, University of Washington
#                     Skye Bender-deMoll, University of Washington
#  For citation information, type citation("network").
#  Type help("network-package") to get started.
#
# sna: Tools for Social Network Analysis
# Version 2.4 created on 2016-07-23.
# copyright (c) 2005, Carter T. Butts, University of California-Irvine
#  For citation information, type citation("sna").
#  Type help(package="sna") to get started.
# [1] "week_1-to-week_2 automated graph correlation = 0.0425015271684107"
# QAP Test Results
#
# Estimated p-values:
# 	p(f(perm) >= f(d)): 0
# 	p(f(perm) <= f(d)): 1
#
# Test Diagnostics:
# 	Test Value (f(d)): 0.04250153
# 	Replications: 1000
# 	Distribution Summary:
# 		Min:	 -0.0004175996
# 		1stQ:	 -0.0004175996
# 		Med:	 -0.0004175996
# 		Mean:	 4.224818e-05
# 		3rdQ:	 -0.0004175996
# 		Max:	 0.01184501
# [1] 2.037711e-05
# [1] "week_1-to-week_2 automated graph covariance = 2.0377110575524e-05"
# QAP Test Results
#
# Estimated p-values:
# 	p(f(perm) >= f(d)): 0
# 	p(f(perm) <= f(d)): 1
#
# Test Diagnostics:
# 	Test Value (f(d)): 2.037711e-05
# 	Replications: 1000
# 	Distribution Summary:
# 		Min:	 -2.002157e-07
# 		1stQ:	 -2.002157e-07
# 		Med:	 -2.002157e-07
# 		Mean:	 1.731603e-08
# 		3rdQ:	 -2.002157e-07
# 		Max:	 4.209211e-06
# Plot with title “Estimated Density of QAP Replications”
# [1] "week_1-to-week_2 automated graph hamming distance = 1186"
# QAP Test Results
#
# Estimated p-values:
# 	p(f(perm) >= f(d)): 1
# 	p(f(perm) <= f(d)): 0
#
# Test Diagnostics:
# 	Test Value (f(d)): 1186
# 	Replications: 1000
# 	Distribution Summary:
# 		Min:	 1206
# 		1stQ:	 1218
# 		Med:	 1218
# 		Mean:	 1217.428
# 		3rdQ:	 1218
# 		Max:	 1218
# Plot with title “Estimated Density of QAP Replications”
# Plot with title “Estimated Density of QAP Replications”

# %% [markdown]
# ## week_1-to-week_2 - human
#
# - Back to [Table of Contents](#Table-of-Contents)

# %%
output_prefix <- "week_1-to-week_2 human"

# %%
# link to good doc on qaptest(){sna} function: http://www.inside-r.org/packages/cran/sna/docs/qaptest

# First, need to load data - see (or just source() ) the file "sna-load_data.r".
# source( "sna-load_data.r" )
# does the following (among other things):
# Start with loading in tab-delimited files.
#humanNetworkData <- read.delim( "human-sourcenet_data-20150504-002453.tab", header = TRUE, row.names = 1, check.names = FALSE )
#calaisNetworkData <- read.delim( "puter-sourcenet_data-20150504-002507.tab", header = TRUE, row.names = 1, check.names = FALSE )

# remove the right-most column, which contains non-tie info on nodes.
#humanNetworkTies <- humanNetworkData[ , -ncol( humanNetworkData ) ]
#gw2HumanNetworkDF <- calaisNetworkData[ , -ncol( calaisNetworkData )]

# convert each to a matrix
#gw2HumanNetworkMatrix <- as.matrix( gw2HumanNetworkTies )
#gw2HumanNetworkMatrix <- as.matrix( gw2HumanNetworkDF )

# imports
# install.packages( "sna" )
# install.packages( "statnet" )
library( "sna" )

# package up data for calling qaptest() - first make 3-dimensional array to hold
#    our two matrices - this is known as a "graph set".
graphSetArray <- array( dim = c( 2, ncol( gw1HumanNetworkMatrix ), nrow( gw1HumanNetworkMatrix ) ) )

# then, place each matrix in one dimension of the array.
graphSetArray[ 1, , ] <- gw1HumanNetworkMatrix
graphSetArray[ 2, , ] <- gw2HumanNetworkMatrix

# first, try a graph correlation
graphCorrelation <- sna::gcor( gw1HumanNetworkMatrix, gw2HumanNetworkMatrix )
paste( output_prefix, "graph correlation =", graphCorrelation, sep = " " )

# try a qaptest...
qapGcorResult <- sna::qaptest( graphSetArray, sna::gcor, g1 = 1, g2 = 2 )
summary( qapGcorResult )
plot( qapGcorResult )

# graph covariance...
graphCovariance <- sna::gcov( gw1HumanNetworkMatrix, gw2HumanNetworkMatrix )
graphCovariance
paste( output_prefix, "graph covariance =", graphCovariance, sep = " " )

# try a qaptest...
qapGcovResult <- sna::qaptest( graphSetArray, sna::gcov, g1 = 1, g2 = 2 )
summary( qapGcovResult )
plot( qapGcovResult )

# Hamming Distance
graphHammingDist <- sna::hdist( gw1HumanNetworkMatrix, gw2HumanNetworkMatrix )
paste( output_prefix, "graph hamming distance =", graphHammingDist, sep = " " )

# try a qaptest...
qapHdistResult <- sna::qaptest( graphSetArray, sna::hdist, g1 = 1, g2 = 2 )
summary( qapHdistResult )
plot( qapHdistResult )

# graph structural correlation?
#graphStructCorrelation <- gscor( gw1HumanNetworkMatrix, gw2HumanNetworkMatrix )
#graphStructCorrelation
# Out:
# [1] "week_1-to-week_2 human graph correlation = 0.0391487901001977"
# QAP Test Results
#
# Estimated p-values:
# 	p(f(perm) >= f(d)): 0
# 	p(f(perm) <= f(d)): 1
#
# Test Diagnostics:
# 	Test Value (f(d)): 0.03914879
# 	Replications: 1000
# 	Distribution Summary:
# 		Min:	 -0.000447151
# 		1stQ:	 -0.000447151
# 		Med:	 -0.000447151
# 		Mean:	 -5.967643e-05
# 		3rdQ:	 -0.000447151
# 		Max:	 0.008037694
# [1] 2.034495e-05
# [1] "week_1-to-week_2 human graph covariance = 2.03449496390699e-05"
# QAP Test Results
#
# Estimated p-values:
# 	p(f(perm) >= f(d)): 0
# 	p(f(perm) <= f(d)): 1
#
# Test Diagnostics:
# 	Test Value (f(d)): 2.034495e-05
# 	Replications: 1000
# 	Distribution Summary:
# 		Min:	 -2.323766e-07
# 		1stQ:	 -2.323766e-07
# 		Med:	 -2.323766e-07
# 		Mean:	 -1.925434e-08
# 		3rdQ:	 -2.323766e-07
# 		Max:	 4.17705e-06
# Plot with title “Estimated Density of QAP Replications”
# [1] "week_1-to-week_2 human graph hamming distance = 1280"
# QAP Test Results
#
# Estimated p-values:
# 	p(f(perm) >= f(d)): 1
# 	p(f(perm) <= f(d)): 0
#
# Test Diagnostics:
# 	Test Value (f(d)): 1280
# 	Replications: 1000
# 	Distribution Summary:
# 		Min:	 1296
# 		1stQ:	 1316
# 		Med:	 1316
# 		Mean:	 1315.432
# 		3rdQ:	 1316
# 		Max:	 1316
# Plot with title “Estimated Density of QAP Replications”
# Plot with title “Estimated Density of QAP Replications”

# %% [markdown]
# # Compare `grp_week_1` and `grp_week_3` using QAP
#
# - Back to [Table of Contents](#Table-of-Contents)
#
# Now, compare the automated and human-coded networks from a week 1 and week 3 to each other, to look at similarity of weeks over time (I'd expect it to be small).
#
# Based on: `sourcenet/R/sna/statnet/sna-qap.r`

# %% [markdown]
# ## week_1-to-week_3 - automated
#
# - Back to [Table of Contents](#Table-of-Contents)

# %%
output_prefix <- "week_1-to-week_3 automated"

# %%
# link to good doc on qaptest(){sna} function: http://www.inside-r.org/packages/cran/sna/docs/qaptest

# First, need to load data - see (or just source() ) the file "sna-load_data.r".
# source( "sna-load_data.r" )
# does the following (among other things):
# Start with loading in tab-delimited files.
#humanNetworkData <- read.delim( "human-sourcenet_data-20150504-002453.tab", header = TRUE, row.names = 1, check.names = FALSE )
#calaisNetworkData <- read.delim( "puter-sourcenet_data-20150504-002507.tab", header = TRUE, row.names = 1, check.names = FALSE )

# remove the right-most column, which contains non-tie info on nodes.
#humanNetworkTies <- humanNetworkData[ , -ncol( humanNetworkData ) ]
#gw3AutomatedNetworkDF <- calaisNetworkData[ , -ncol( calaisNetworkData )]

# convert each to a matrix
#gw3HumanNetworkMatrix <- as.matrix( gw3HumanNetworkTies )
#gw3AutomatedNetworkMatrix <- as.matrix( gw3AutomatedNetworkDF )

# imports
# install.packages( "sna" )
# install.packages( "statnet" )
library( "sna" )

# package up data for calling qaptest() - first make 3-dimensional array to hold
#    our two matrices - this is known as a "graph set".
graphSetArray <- array( dim = c( 2, ncol( gw1AutomatedNetworkMatrix ), nrow( gw1AutomatedNetworkMatrix ) ) )

# then, place each matrix in one dimension of the array.
graphSetArray[ 1, , ] <- gw1AutomatedNetworkMatrix
graphSetArray[ 2, , ] <- gw3AutomatedNetworkMatrix

# first, try a graph correlation
graphCorrelation <- sna::gcor( gw1AutomatedNetworkMatrix, gw3AutomatedNetworkMatrix )
paste( output_prefix, "graph correlation =", graphCorrelation, sep = " " )

# try a qaptest...
qapGcorResult <- sna::qaptest( graphSetArray, sna::gcor, g1 = 1, g2 = 2 )
summary( qapGcorResult )
plot( qapGcorResult )

# graph covariance...
graphCovariance <- sna::gcov( gw1AutomatedNetworkMatrix, gw3AutomatedNetworkMatrix )
graphCovariance
paste( output_prefix, "graph covariance =", graphCovariance, sep = " " )

# try a qaptest...
qapGcovResult <- sna::qaptest( graphSetArray, sna::gcov, g1 = 1, g2 = 2 )
summary( qapGcovResult )
plot( qapGcovResult )

# Hamming Distance
graphHammingDist <- sna::hdist( gw1AutomatedNetworkMatrix, gw3AutomatedNetworkMatrix )
paste( output_prefix, "graph hamming distance =", graphHammingDist, sep = " " )

# try a qaptest...
qapHdistResult <- sna::qaptest( graphSetArray, sna::hdist, g1 = 1, g2 = 2 )
summary( qapHdistResult )
plot( qapHdistResult )

# graph structural correlation?
#graphStructCorrelation <- gscor( gw3HumanNetworkMatrix, gw3AutomatedNetworkMatrix )
#graphStructCorrelation
# Out:
# [1] "week_1-to-week_3 automated graph correlation = 0.0262884654712309"
# QAP Test Results
#
# Estimated p-values:
# 	p(f(perm) >= f(d)): 0
# 	p(f(perm) <= f(d)): 1
#
# Test Diagnostics:
# 	Test Value (f(d)): 0.02628847
# 	Replications: 1000
# 	Distribution Summary:
# 		Min:	 -0.0003917907
# 		1stQ:	 -0.0003917907
# 		Med:	 -0.0003917907
# 		Mean:	 5.176857e-05
# 		3rdQ:	 -0.0003917907
# 		Max:	 0.009613305
# [1] 1.15858e-05
# [1] "week_1-to-week_3 automated graph covariance = 1.1585802910022e-05"
# QAP Test Results
#
# Estimated p-values:
# 	p(f(perm) >= f(d)): 0
# 	p(f(perm) <= f(d)): 1
#
# Test Diagnostics:
# 	Test Value (f(d)): 1.15858e-05
# 	Replications: 1000
# 	Distribution Summary:
# 		Min:	 -1.726693e-07
# 		1stQ:	 -1.726693e-07
# 		Med:	 -1.726693e-07
# 		Mean:	 -7.015975e-10
# 		3rdQ:	 -1.726693e-07
# 		Max:	 4.236758e-06
# Plot with title “Estimated Density of QAP Replications”
# [1] "week_1-to-week_3 automated graph hamming distance = 1112"
# QAP Test Results
#
# Estimated p-values:
# 	p(f(perm) >= f(d)): 1
# 	p(f(perm) <= f(d)): 0
#
# Test Diagnostics:
# 	Test Value (f(d)): 1112
# 	Replications: 1000
# 	Distribution Summary:
# 		Min:	 1124
# 		1stQ:	 1136
# 		Med:	 1136
# 		Mean:	 1135.592
# 		3rdQ:	 1136
# 		Max:	 1136
# Plot with title “Estimated Density of QAP Replications”
# Plot with title “Estimated Density of QAP Replications”

# %% [markdown]
# ## week_1-to-week_3 - human
#
# - Back to [Table of Contents](#Table-of-Contents)

# %%
output_prefix <- "week_1-to-week_3 human"

# %%
# link to good doc on qaptest(){sna} function: http://www.inside-r.org/packages/cran/sna/docs/qaptest

# First, need to load data - see (or just source() ) the file "sna-load_data.r".
# source( "sna-load_data.r" )
# does the following (among other things):
# Start with loading in tab-delimited files.
#humanNetworkData <- read.delim( "human-sourcenet_data-20150504-002453.tab", header = TRUE, row.names = 1, check.names = FALSE )
#calaisNetworkData <- read.delim( "puter-sourcenet_data-20150504-002507.tab", header = TRUE, row.names = 1, check.names = FALSE )

# remove the right-most column, which contains non-tie info on nodes.
#humanNetworkTies <- humanNetworkData[ , -ncol( humanNetworkData ) ]
#gw3HumanNetworkDF <- calaisNetworkData[ , -ncol( calaisNetworkData )]

# convert each to a matrix
#gw3HumanNetworkMatrix <- as.matrix( gw3HumanNetworkTies )
#gw3HumanNetworkMatrix <- as.matrix( gw3HumanNetworkDF )

# imports
# install.packages( "sna" )
# install.packages( "statnet" )
library( "sna" )

# package up data for calling qaptest() - first make 3-dimensional array to hold
#    our two matrices - this is known as a "graph set".
graphSetArray <- array( dim = c( 2, ncol( gw1HumanNetworkMatrix ), nrow( gw1HumanNetworkMatrix ) ) )

# then, place each matrix in one dimension of the array.
graphSetArray[ 1, , ] <- gw1HumanNetworkMatrix
graphSetArray[ 2, , ] <- gw3HumanNetworkMatrix

# first, try a graph correlation
graphCorrelation <- sna::gcor( gw1HumanNetworkMatrix, gw3HumanNetworkMatrix )
paste( output_prefix, "graph correlation =", graphCorrelation, sep = " " )

# try a qaptest...
qapGcorResult <- sna::qaptest( graphSetArray, sna::gcor, g1 = 1, g2 = 2 )
summary( qapGcorResult )
plot( qapGcorResult )

# graph covariance...
graphCovariance <- sna::gcov( gw1HumanNetworkMatrix, gw3HumanNetworkMatrix )
graphCovariance
paste( output_prefix, "graph covariance =", graphCovariance, sep = " " )

# try a qaptest...
qapGcovResult <- sna::qaptest( graphSetArray, sna::gcov, g1 = 1, g2 = 2 )
summary( qapGcovResult )
plot( qapGcovResult )

# Hamming Distance
graphHammingDist <- sna::hdist( gw1HumanNetworkMatrix, gw3HumanNetworkMatrix )
paste( output_prefix, "graph hamming distance =", graphHammingDist, sep = " " )

# try a qaptest...
qapHdistResult <- sna::qaptest( graphSetArray, sna::hdist, g1 = 1, g2 = 2 )
summary( qapHdistResult )
plot( qapHdistResult )

# graph structural correlation?
#graphStructCorrelation <- gscor( gw1HumanNetworkMatrix, gw3HumanNetworkMatrix )
#graphStructCorrelation
# Out:
# [1] "week_1-to-week_3 human graph correlation = 0.0269444521618076"
# QAP Test Results
#
# Estimated p-values:
# 	p(f(perm) >= f(d)): 0
# 	p(f(perm) <= f(d)): 1
#
# Test Diagnostics:
# 	Test Value (f(d)): 0.02694445
# 	Replications: 1000
# 	Distribution Summary:
# 		Min:	 -0.0004300933
# 		1stQ:	 -0.0004300933
# 		Med:	 -0.0004300933
# 		Mean:	 1.816231e-06
# 		3rdQ:	 -0.0004300933
# 		Max:	 0.01173637
# [1] 1.302045e-05
# [1] "week_1-to-week_3 human graph covariance = 1.30204459652099e-05"
# QAP Test Results
#
# Estimated p-values:
# 	p(f(perm) >= f(d)): 0
# 	p(f(perm) <= f(d)): 1
#
# Test Diagnostics:
# 	Test Value (f(d)): 1.302045e-05
# 	Replications: 1000
# 	Distribution Summary:
# 		Min:	 -2.078352e-07
# 		1stQ:	 -2.078352e-07
# 		Med:	 -2.078352e-07
# 		Mean:	 1.116633e-08
# 		3rdQ:	 -2.078352e-07
# 		Max:	 5.671401e-06
# Plot with title “Estimated Density of QAP Replications”
# [1] "week_1-to-week_3 human graph hamming distance = 1224"
# QAP Test Results
#
# Estimated p-values:
# 	p(f(perm) >= f(d)): 1
# 	p(f(perm) <= f(d)): 0
#
# Test Diagnostics:
# 	Test Value (f(d)): 1224
# 	Replications: 1000
# 	Distribution Summary:
# 		Min:	 1240
# 		1stQ:	 1252
# 		Med:	 1252
# 		Mean:	 1251.468
# 		3rdQ:	 1252
# 		Max:	 1252
# Plot with title “Estimated Density of QAP Replications”
# Plot with title “Estimated Density of QAP Replications”

# %% [markdown]
# # Compare `grp_week_2` and `grp_week_3` using QAP
#
# - Back to [Table of Contents](#Table-of-Contents)
#
# Now, compare the automated and human-coded networks from a week 2 and week 3 to each other, to look at similarity of weeks over time (I'd expect it to be small).
#
# Based on: `sourcenet/R/sna/statnet/sna-qap.r`

# %% [markdown]
# ## week_2-to-week_3 - automated
#
# - Back to [Table of Contents](#Table-of-Contents)

# %%
output_prefix <- "week_2-to-week_3 automated"

# %%
# link to good doc on qaptest(){sna} function: http://www.inside-r.org/packages/cran/sna/docs/qaptest

# First, need to load data - see (or just source() ) the file "sna-load_data.r".
# source( "sna-load_data.r" )
# does the following (among other things):
# Start with loading in tab-delimited files.
#humanNetworkData <- read.delim( "human-sourcenet_data-20150504-002453.tab", header = TRUE, row.names = 1, check.names = FALSE )
#calaisNetworkData <- read.delim( "puter-sourcenet_data-20150504-002507.tab", header = TRUE, row.names = 1, check.names = FALSE )

# remove the right-most column, which contains non-tie info on nodes.
#humanNetworkTies <- humanNetworkData[ , -ncol( humanNetworkData ) ]
#gw3AutomatedNetworkDF <- calaisNetworkData[ , -ncol( calaisNetworkData )]

# convert each to a matrix
#gw3HumanNetworkMatrix <- as.matrix( gw3HumanNetworkTies )
#gw3AutomatedNetworkMatrix <- as.matrix( gw3AutomatedNetworkDF )

# imports
# install.packages( "sna" )
# install.packages( "statnet" )
library( "sna" )

# package up data for calling qaptest() - first make 3-dimensional array to hold
#    our two matrices - this is known as a "graph set".
graphSetArray <- array( dim = c( 2, ncol( gw2AutomatedNetworkMatrix ), nrow( gw2AutomatedNetworkMatrix ) ) )

# then, place each matrix in one dimension of the array.
graphSetArray[ 1, , ] <- gw2AutomatedNetworkMatrix
graphSetArray[ 2, , ] <- gw3AutomatedNetworkMatrix

# first, try a graph correlation
graphCorrelation <- sna::gcor( gw2AutomatedNetworkMatrix, gw3AutomatedNetworkMatrix )
paste( output_prefix, "graph correlation =", graphCorrelation, sep = " " )

# try a qaptest...
qapGcorResult <- sna::qaptest( graphSetArray, sna::gcor, g1 = 1, g2 = 2 )
summary( qapGcorResult )
plot( qapGcorResult )

# graph covariance...
graphCovariance <- sna::gcov( gw2AutomatedNetworkMatrix, gw3AutomatedNetworkMatrix )
graphCovariance
paste( output_prefix, "graph covariance =", graphCovariance, sep = " " )

# try a qaptest...
qapGcovResult <- sna::qaptest( graphSetArray, sna::gcov, g1 = 1, g2 = 2 )
summary( qapGcovResult )
plot( qapGcovResult )

# Hamming Distance
graphHammingDist <- sna::hdist( gw2AutomatedNetworkMatrix, gw3AutomatedNetworkMatrix )
paste( output_prefix, "graph hamming distance =", graphHammingDist, sep = " " )

# try a qaptest...
qapHdistResult <- sna::qaptest( graphSetArray, sna::hdist, g1 = 1, g2 = 2 )
summary( qapHdistResult )
plot( qapHdistResult )

# graph structural correlation?
#graphStructCorrelation <- gscor( gw3HumanNetworkMatrix, gw3AutomatedNetworkMatrix )
#graphStructCorrelation
# Out:
# [1] "week_2-to-week_3 automated graph correlation = 0.0237206678784088"
# QAP Test Results
#
# Estimated p-values:
# 	p(f(perm) >= f(d)): 0
# 	p(f(perm) <= f(d)): 1
#
# Test Diagnostics:
# 	Test Value (f(d)): 0.02372067
# 	Replications: 1000
# 	Distribution Summary:
# 		Min:	 -0.0003876854
# 		1stQ:	 -0.0003876854
# 		Med:	 -0.0003876854
# 		Mean:	 -1.917203e-05
# 		3rdQ:	 -0.0003876854
# 		Max:	 0.006500416
# [1] 1.012321e-05
# [1] "week_2-to-week_3 automated graph covariance = 1.01232115754695e-05"
# QAP Test Results
#
# Estimated p-values:
# 	p(f(perm) >= f(d)): 0
# 	p(f(perm) <= f(d)): 1
#
# Test Diagnostics:
# 	Test Value (f(d)): 1.012321e-05
# 	Replications: 1000
# 	Distribution Summary:
# 		Min:	 -1.654516e-07
# 		1stQ:	 -1.654516e-07
# 		Med:	 -1.654516e-07
# 		Mean:	 1.974437e-08
# 		3rdQ:	 -1.654516e-07
# 		Max:	 5.713785e-06
# Plot with title “Estimated Density of QAP Replications”
# [1] "week_2-to-week_3 automated graph hamming distance = 1082"
# QAP Test Results
#
# Estimated p-values:
# 	p(f(perm) >= f(d)): 1
# 	p(f(perm) <= f(d)): 0
#
# Test Diagnostics:
# 	Test Value (f(d)): 1082
# 	Replications: 1000
# 	Distribution Summary:
# 		Min:	 1102
# 		1stQ:	 1110
# 		Med:	 1110
# 		Mean:	 1109.532
# 		3rdQ:	 1110
# 		Max:	 1110
# Plot with title “Estimated Density of QAP Replications”
# Plot with title “Estimated Density of QAP Replications”

# %% [markdown]
# ## week_2-to-week_3 - human
#
# - Back to [Table of Contents](#Table-of-Contents)

# %%
output_prefix <- "week_2-to-week_3 human"

# %%
# link to good doc on qaptest(){sna} function: http://www.inside-r.org/packages/cran/sna/docs/qaptest

# First, need to load data - see (or just source() ) the file "sna-load_data.r".
# source( "sna-load_data.r" )
# does the following (among other things):
# Start with loading in tab-delimited files.
#humanNetworkData <- read.delim( "human-sourcenet_data-20150504-002453.tab", header = TRUE, row.names = 1, check.names = FALSE )
#calaisNetworkData <- read.delim( "puter-sourcenet_data-20150504-002507.tab", header = TRUE, row.names = 1, check.names = FALSE )

# remove the right-most column, which contains non-tie info on nodes.
#humanNetworkTies <- humanNetworkData[ , -ncol( humanNetworkData ) ]
#gw3HumanNetworkDF <- calaisNetworkData[ , -ncol( calaisNetworkData )]

# convert each to a matrix
#gw3HumanNetworkMatrix <- as.matrix( gw3HumanNetworkTies )
#gw3HumanNetworkMatrix <- as.matrix( gw3HumanNetworkDF )

# imports
# install.packages( "sna" )
# install.packages( "statnet" )
library( "sna" )

# package up data for calling qaptest() - first make 3-dimensional array to hold
#    our two matrices - this is known as a "graph set".
graphSetArray <- array( dim = c( 2, ncol( gw2HumanNetworkMatrix ), nrow( gw2HumanNetworkMatrix ) ) )

# then, place each matrix in one dimension of the array.
graphSetArray[ 1, , ] <- gw2HumanNetworkMatrix
graphSetArray[ 2, , ] <- gw3HumanNetworkMatrix

# first, try a graph correlation
graphCorrelation <- sna::gcor( gw2HumanNetworkMatrix, gw3HumanNetworkMatrix )
paste( output_prefix, "graph correlation =", graphCorrelation, sep = " " )

# try a qaptest...
qapGcorResult <- sna::qaptest( graphSetArray, sna::gcor, g1 = 1, g2 = 2 )
summary( qapGcorResult )
plot( qapGcorResult )

# graph covariance...
graphCovariance <- sna::gcov( gw2HumanNetworkMatrix, gw3HumanNetworkMatrix )
graphCovariance
paste( output_prefix, "graph covariance =", graphCovariance, sep = " " )

# try a qaptest...
qapGcovResult <- sna::qaptest( graphSetArray, sna::gcov, g1 = 1, g2 = 2 )
summary( qapGcovResult )
plot( qapGcovResult )

# Hamming Distance
graphHammingDist <- sna::hdist( gw2HumanNetworkMatrix, gw3HumanNetworkMatrix )
paste( output_prefix, "graph hamming distance =", graphHammingDist, sep = " " )

# try a qaptest...
qapHdistResult <- sna::qaptest( graphSetArray, sna::hdist, g1 = 1, g2 = 2 )
summary( qapHdistResult )
plot( qapHdistResult )

# graph structural correlation?
#graphStructCorrelation <- gscor( gw2HumanNetworkMatrix, gw3HumanNetworkMatrix )
#graphStructCorrelation
# Out:
# [1] "week_2-to-week_3 human graph correlation = 0.0293939514488537"
# QAP Test Results
#
# Estimated p-values:
# 	p(f(perm) >= f(d)): 0
# 	p(f(perm) <= f(d)): 1
#
# Test Diagnostics:
# 	Test Value (f(d)): 0.02939395
# 	Replications: 1000
# 	Distribution Summary:
# 		Min:	 -0.0003995317
# 		1stQ:	 -0.0003995317
# 		Med:	 -0.0003995317
# 		Mean:	 -2.214761e-05
# 		3rdQ:	 -0.0003995317
# 		Max:	 0.009531629
# [1] 1.305089e-05
# [1] "week_2-to-week_3 human graph covariance = 1.30508894337734e-05"
# QAP Test Results
#
# Estimated p-values:
# 	p(f(perm) >= f(d)): 0
# 	p(f(perm) <= f(d)): 1
#
# Test Diagnostics:
# 	Test Value (f(d)): 1.305089e-05
# 	Replications: 1000
# 	Distribution Summary:
# 		Min:	 -1.773917e-07
# 		1stQ:	 -1.773917e-07
# 		Med:	 -1.773917e-07
# 		Mean:	 -8.363712e-09
# 		3rdQ:	 -1.773917e-07
# 		Max:	 5.701844e-06
# Plot with title “Estimated Density of QAP Replications”
# [1] "week_2-to-week_3 human graph hamming distance = 1116"
# QAP Test Results
#
# Estimated p-values:
# 	p(f(perm) >= f(d)): 1
# 	p(f(perm) <= f(d)): 0
#
# Test Diagnostics:
# 	Test Value (f(d)): 1116
# 	Replications: 1000
# 	Distribution Summary:
# 		Min:	 1136
# 		1stQ:	 1148
# 		Med:	 1148
# 		Mean:	 1147.532
# 		3rdQ:	 1148
# 		Max:	 1148
# Plot with title “Estimated Density of QAP Replications”
# Plot with title “Estimated Density of QAP Replications”

# %% [markdown]
# # Compare `grp_month` and `grp_week_1` using QAP
#
# - Back to [Table of Contents](#Table-of-Contents)
#
# Now, compare the automated and human-coded networks from the full month and week 1 against each other, to see what more time gets you.
#
# Based on: `sourcenet/R/sna/statnet/sna-qap.r`

# %% [markdown]
# ## month-to-week_1 - automated
#
# - Back to [Table of Contents](#Table-of-Contents)

# %%
output_prefix <- "month-to-week_1 automated"

# %%
# link to good doc on qaptest(){sna} function: http://www.inside-r.org/packages/cran/sna/docs/qaptest

# First, need to load data - see (or just source() ) the file "sna-load_data.r".
# source( "sna-load_data.r" )
# does the following (among other things):
# Start with loading in tab-delimited files.
#humanNetworkData <- read.delim( "human-sourcenet_data-20150504-002453.tab", header = TRUE, row.names = 1, check.names = FALSE )
#calaisNetworkData <- read.delim( "puter-sourcenet_data-20150504-002507.tab", header = TRUE, row.names = 1, check.names = FALSE )

# remove the right-most column, which contains non-tie info on nodes.
#humanNetworkTies <- humanNetworkData[ , -ncol( humanNetworkData ) ]
#gw1AutomatedNetworkDF <- calaisNetworkData[ , -ncol( calaisNetworkData )]

# convert each to a matrix
#gw1HumanNetworkMatrix <- as.matrix( gw1HumanNetworkTies )
#gw1AutomatedNetworkMatrix <- as.matrix( gw1AutomatedNetworkDF )

# imports
# install.packages( "sna" )
# install.packages( "statnet" )
library( "sna" )

# package up data for calling qaptest() - first make 3-dimensional array to hold
#    our two matrices - this is known as a "graph set".
graphSetArray <- array( dim = c( 2, ncol( gmAutomatedNetworkMatrix ), nrow( gmAutomatedNetworkMatrix ) ) )

# then, place each matrix in one dimension of the array.
graphSetArray[ 1, , ] <- gmAutomatedNetworkMatrix
graphSetArray[ 2, , ] <- gw1AutomatedNetworkMatrix

# first, try a graph correlation
graphCorrelation <- sna::gcor( gmAutomatedNetworkMatrix, gw1AutomatedNetworkMatrix )
paste( output_prefix, "graph correlation =", graphCorrelation, sep = " " )

# try a qaptest...
qapGcorResult <- sna::qaptest( graphSetArray, sna::gcor, g1 = 1, g2 = 2 )
summary( qapGcorResult )
plot( qapGcorResult )

# graph covariance...
graphCovariance <- sna::gcov( gmAutomatedNetworkMatrix, gw1AutomatedNetworkMatrix )
graphCovariance
paste( output_prefix, "graph covariance =", graphCovariance, sep = " " )

# try a qaptest...
qapGcovResult <- sna::qaptest( graphSetArray, sna::gcov, g1 = 1, g2 = 2 )
summary( qapGcovResult )
plot( qapGcovResult )

# Hamming Distance
graphHammingDist <- sna::hdist( gmAutomatedNetworkMatrix, gw1AutomatedNetworkMatrix )
paste( output_prefix, "graph hamming distance =", graphHammingDist, sep = " " )

# try a qaptest...
qapHdistResult <- sna::qaptest( graphSetArray, sna::hdist, g1 = 1, g2 = 2 )
summary( qapHdistResult )
plot( qapHdistResult )

# graph structural correlation?
#graphStructCorrelation <- gscor( gw1HumanNetworkMatrix, gw1AutomatedNetworkMatrix )
#graphStructCorrelation
# Out:
# [1] "month-to-week_1 automated graph correlation = 0.521381854496348"
# QAP Test Results
#
# Estimated p-values:
# 	p(f(perm) >= f(d)): 0
# 	p(f(perm) <= f(d)): 1
#
# Test Diagnostics:
# 	Test Value (f(d)): 0.5213819
# 	Replications: 1000
# 	Distribution Summary:
# 		Min:	 -0.0007992741
# 		1stQ:	 -0.0007992741
# 		Med:	 -0.0007992741
# 		Mean:	 -4.890125e-05
# 		3rdQ:	 0.0006006753
# 		Max:	 0.006200473
# [1] 0.0005473996
# [1] "month-to-week_1 automated graph covariance = 0.000547399605464319"
# QAP Test Results
#
# Estimated p-values:
# 	p(f(perm) >= f(d)): 0
# 	p(f(perm) <= f(d)): 1
#
# Test Diagnostics:
# 	Test Value (f(d)): 0.0005473996
# 	Replications: 1000
# 	Distribution Summary:
# 		Min:	 -8.391591e-07
# 		1stQ:	 -8.391591e-07
# 		Med:	 -8.391591e-07
# 		Mean:	 3.537724e-08
# 		3rdQ:	 6.306499e-07
# 		Max:	 2.414759e-05
# Plot with title “Estimated Density of QAP Replications”
# [1] "month-to-week_1 automated graph hamming distance = 1876"
# QAP Test Results
#
# Estimated p-values:
# 	p(f(perm) >= f(d)): 1
# 	p(f(perm) <= f(d)): 0
#
# Test Diagnostics:
# 	Test Value (f(d)): 1876
# 	Replications: 1000
# 	Distribution Summary:
# 		Min:	 3096
# 		1stQ:	 3116
# 		Med:	 3120
# 		Mean:	 3118.044
# 		3rdQ:	 3120
# 		Max:	 3120
# Plot with title “Estimated Density of QAP Replications”
# Plot with title “Estimated Density of QAP Replications”

# %% [markdown]
# ## month-to-week_1 - human
#
# - Back to [Table of Contents](#Table-of-Contents)

# %%
output_prefix <- "month-to-week_1 human"

# %%
# link to good doc on qaptest(){sna} function: http://www.inside-r.org/packages/cran/sna/docs/qaptest

# First, need to load data - see (or just source() ) the file "sna-load_data.r".
# source( "sna-load_data.r" )
# does the following (among other things):
# Start with loading in tab-delimited files.
#humanNetworkData <- read.delim( "human-sourcenet_data-20150504-002453.tab", header = TRUE, row.names = 1, check.names = FALSE )
#calaisNetworkData <- read.delim( "puter-sourcenet_data-20150504-002507.tab", header = TRUE, row.names = 1, check.names = FALSE )

# remove the right-most column, which contains non-tie info on nodes.
#humanNetworkTies <- humanNetworkData[ , -ncol( humanNetworkData ) ]
#gw1HumanNetworkDF <- calaisNetworkData[ , -ncol( calaisNetworkData )]

# convert each to a matrix
#gw1HumanNetworkMatrix <- as.matrix( gw1HumanNetworkTies )
#gw1HumanNetworkMatrix <- as.matrix( gw1HumanNetworkDF )

# imports
# install.packages( "sna" )
# install.packages( "statnet" )
library( "sna" )

# package up data for calling qaptest() - first make 3-dimensional array to hold
#    our two matrices - this is known as a "graph set".
graphSetArray <- array( dim = c( 2, ncol( gmHumanNetworkMatrix ), nrow( gmHumanNetworkMatrix ) ) )

# then, place each matrix in one dimension of the array.
graphSetArray[ 1, , ] <- gmHumanNetworkMatrix
graphSetArray[ 2, , ] <- gw1HumanNetworkMatrix

# first, try a graph correlation
graphCorrelation <- sna::gcor( gmHumanNetworkMatrix, gw1HumanNetworkMatrix )
paste( output_prefix, "graph correlation =", graphCorrelation, sep = " " )

# try a qaptest...
qapGcorResult <- sna::qaptest( graphSetArray, sna::gcor, g1 = 1, g2 = 2 )
summary( qapGcorResult )
plot( qapGcorResult )

# graph covariance...
graphCovariance <- sna::gcov( gmHumanNetworkMatrix, gw1HumanNetworkMatrix )
graphCovariance
paste( output_prefix, "graph covariance =", graphCovariance, sep = " " )

# try a qaptest...
qapGcovResult <- sna::qaptest( graphSetArray, sna::gcov, g1 = 1, g2 = 2 )
summary( qapGcovResult )
plot( qapGcovResult )

# Hamming Distance
graphHammingDist <- sna::hdist( gmHumanNetworkMatrix, gw1HumanNetworkMatrix )
paste( output_prefix, "graph hamming distance =", graphHammingDist, sep = " " )

# try a qaptest...
qapHdistResult <- sna::qaptest( graphSetArray, sna::hdist, g1 = 1, g2 = 2 )
summary( qapHdistResult )
plot( qapHdistResult )

# graph structural correlation?
#graphStructCorrelation <- gscor( gmHumanNetworkMatrix, gw1HumanNetworkMatrix )
#graphStructCorrelation
# Out:
# [1] "month-to-week_1 human graph correlation = 0.538643365355464"
# QAP Test Results
#
# Estimated p-values:
# 	p(f(perm) >= f(d)): 0
# 	p(f(perm) <= f(d)): 1
#
# Test Diagnostics:
# 	Test Value (f(d)): 0.5386434
# 	Replications: 1000
# 	Distribution Summary:
# 		Min:	 -0.0008668826
# 		1stQ:	 -0.0008668826
# 		Med:	 -0.0008668826
# 		Mean:	 6.670216e-06
# 		3rdQ:	 0.0003936554
# 		Max:	 0.01930172
# [1] 0.0006280675
# [1] "month-to-week_1 human graph covariance = 0.000628067460651923"
# QAP Test Results
#
# Estimated p-values:
# 	p(f(perm) >= f(d)): 0
# 	p(f(perm) <= f(d)): 1
#
# Test Diagnostics:
# 	Test Value (f(d)): 0.0006280675
# 	Replications: 1000
# 	Distribution Summary:
# 		Min:	 -1.0108e-06
# 		1stQ:	 -1.0108e-06
# 		Med:	 -1.0108e-06
# 		Mean:	 1.365682e-08
# 		3rdQ:	 4.59009e-07
# 		Max:	 1.074767e-05
# Plot with title “Estimated Density of QAP Replications”
# [1] "month-to-week_1 human graph hamming distance = 1926"
# QAP Test Results
#
# Estimated p-values:
# 	p(f(perm) >= f(d)): 1
# 	p(f(perm) <= f(d)): 0
#
# Test Diagnostics:
# 	Test Value (f(d)): 1926
# 	Replications: 1000
# 	Distribution Summary:
# 		Min:	 3326
# 		1stQ:	 3342
# 		Med:	 3346
# 		Mean:	 3343.572
# 		3rdQ:	 3346
# 		Max:	 3346
# Plot with title “Estimated Density of QAP Replications”
# Plot with title “Estimated Density of QAP Replications”

# %% [markdown]
# # Compare `grp_month` and `grp_week_2` using QAP
#
# - Back to [Table of Contents](#Table-of-Contents)
#
# Now, compare the automated and human-coded networks from the full month and week 2 against each other, to see what more time gets you.
#
# Based on: `sourcenet/R/sna/statnet/sna-qap.r`

# %% [markdown]
# ## month-to-week_2 - automated
#
# - Back to [Table of Contents](#Table-of-Contents)

# %%
output_prefix <- "month-to-week_2 automated"

# %%
# link to good doc on qaptest(){sna} function: http://www.inside-r.org/packages/cran/sna/docs/qaptest

# First, need to load data - see (or just source() ) the file "sna-load_data.r".
# source( "sna-load_data.r" )
# does the following (among other things):
# Start with loading in tab-delimited files.
#humanNetworkData <- read.delim( "human-sourcenet_data-20150504-002453.tab", header = TRUE, row.names = 1, check.names = FALSE )
#calaisNetworkData <- read.delim( "puter-sourcenet_data-20150504-002507.tab", header = TRUE, row.names = 1, check.names = FALSE )

# remove the right-most column, which contains non-tie info on nodes.
#humanNetworkTies <- humanNetworkData[ , -ncol( humanNetworkData ) ]
#gw2AutomatedNetworkDF <- calaisNetworkData[ , -ncol( calaisNetworkData )]

# convert each to a matrix
#gw2HumanNetworkMatrix <- as.matrix( gw2HumanNetworkTies )
#gw2AutomatedNetworkMatrix <- as.matrix( gw2AutomatedNetworkDF )

# imports
# install.packages( "sna" )
# install.packages( "statnet" )
library( "sna" )

# package up data for calling qaptest() - first make 3-dimensional array to hold
#    our two matrices - this is known as a "graph set".
graphSetArray <- array( dim = c( 2, ncol( gmAutomatedNetworkMatrix ), nrow( gmAutomatedNetworkMatrix ) ) )

# then, place each matrix in one dimension of the array.
graphSetArray[ 1, , ] <- gmAutomatedNetworkMatrix
graphSetArray[ 2, , ] <- gw2AutomatedNetworkMatrix

# first, try a graph correlation
graphCorrelation <- sna::gcor( gmAutomatedNetworkMatrix, gw2AutomatedNetworkMatrix )
paste( output_prefix, "graph correlation =", graphCorrelation, sep = " " )

# try a qaptest...
qapGcorResult <- sna::qaptest( graphSetArray, sna::gcor, g1 = 1, g2 = 2 )
summary( qapGcorResult )
plot( qapGcorResult )

# graph covariance...
graphCovariance <- sna::gcov( gmAutomatedNetworkMatrix, gw2AutomatedNetworkMatrix )
graphCovariance
paste( output_prefix, "graph covariance =", graphCovariance, sep = " " )

# try a qaptest...
qapGcovResult <- sna::qaptest( graphSetArray, sna::gcov, g1 = 1, g2 = 2 )
summary( qapGcovResult )
plot( qapGcovResult )

# Hamming Distance
graphHammingDist <- sna::hdist( gmAutomatedNetworkMatrix, gw2AutomatedNetworkMatrix )
paste( output_prefix, "graph hamming distance =", graphHammingDist, sep = " " )

# try a qaptest...
qapHdistResult <- sna::qaptest( graphSetArray, sna::hdist, g1 = 1, g2 = 2 )
summary( qapHdistResult )
plot( qapHdistResult )

# graph structural correlation?
#graphStructCorrelation <- gscor( gw2HumanNetworkMatrix, gw2AutomatedNetworkMatrix )
#graphStructCorrelation
# Out:
# [1] "month-to-week_2 automated graph correlation = 0.526894046954591"
# QAP Test Results
#
# Estimated p-values:
# 	p(f(perm) >= f(d)): 0
# 	p(f(perm) <= f(d)): 1
#
# Test Diagnostics:
# 	Test Value (f(d)): 0.526894
# 	Replications: 1000
# 	Distribution Summary:
# 		Min:	 -0.0007908992
# 		1stQ:	 -0.0007908992
# 		Med:	 -0.0007908992
# 		Mean:	 -6.80431e-05
# 		3rdQ:	 0.000654813
# 		Max:	 0.006437662
# [1] 0.0005356762
# [1] "month-to-week_2 automated graph covariance = 0.000535676210692771"
# QAP Test Results
#
# Estimated p-values:
# 	p(f(perm) >= f(d)): 0
# 	p(f(perm) <= f(d)): 1
#
# Test Diagnostics:
# 	Test Value (f(d)): 0.0005356762
# 	Replications: 1000
# 	Distribution Summary:
# 		Min:	 -8.040817e-07
# 		1stQ:	 -8.040817e-07
# 		Med:	 -8.040817e-07
# 		Mean:	 -2.508296e-08
# 		3rdQ:	 6.657273e-07
# 		Max:	 6.544963e-06
# Plot with title “Estimated Density of QAP Replications”
# [1] "month-to-week_2 automated graph hamming distance = 1902"
# QAP Test Results
#
# Estimated p-values:
# 	p(f(perm) >= f(d)): 1
# 	p(f(perm) <= f(d)): 0
#
# Test Diagnostics:
# 	Test Value (f(d)): 1902
# 	Replications: 1000
# 	Distribution Summary:
# 		Min:	 3078
# 		1stQ:	 3090
# 		Med:	 3094
# 		Mean:	 3092.076
# 		3rdQ:	 3094
# 		Max:	 3094
# Plot with title “Estimated Density of QAP Replications”
# Plot with title “Estimated Density of QAP Replications”

# %% [markdown]
# ## month-to-week_2 - human
#
# - Back to [Table of Contents](#Table-of-Contents)

# %%
output_prefix <- "month-to-week_2 human"

# %%
# link to good doc on qaptest(){sna} function: http://www.inside-r.org/packages/cran/sna/docs/qaptest

# First, need to load data - see (or just source() ) the file "sna-load_data.r".
# source( "sna-load_data.r" )
# does the following (among other things):
# Start with loading in tab-delimited files.
#humanNetworkData <- read.delim( "human-sourcenet_data-20150504-002453.tab", header = TRUE, row.names = 1, check.names = FALSE )
#calaisNetworkData <- read.delim( "puter-sourcenet_data-20150504-002507.tab", header = TRUE, row.names = 1, check.names = FALSE )

# remove the right-most column, which contains non-tie info on nodes.
#humanNetworkTies <- humanNetworkData[ , -ncol( humanNetworkData ) ]
#gw2HumanNetworkDF <- calaisNetworkData[ , -ncol( calaisNetworkData )]

# convert each to a matrix
#gw2HumanNetworkMatrix <- as.matrix( gw2HumanNetworkTies )
#gw2HumanNetworkMatrix <- as.matrix( gw2HumanNetworkDF )

# imports
# install.packages( "sna" )
# install.packages( "statnet" )
library( "sna" )

# package up data for calling qaptest() - first make 3-dimensional array to hold
#    our two matrices - this is known as a "graph set".
graphSetArray <- array( dim = c( 2, ncol( gmHumanNetworkMatrix ), nrow( gmHumanNetworkMatrix ) ) )

# then, place each matrix in one dimension of the array.
graphSetArray[ 1, , ] <- gmHumanNetworkMatrix
graphSetArray[ 2, , ] <- gw2HumanNetworkMatrix

# first, try a graph correlation
graphCorrelation <- sna::gcor( gmHumanNetworkMatrix, gw2HumanNetworkMatrix )
paste( output_prefix, "graph correlation =", graphCorrelation, sep = " " )

# try a qaptest...
qapGcorResult <- sna::qaptest( graphSetArray, sna::gcor, g1 = 1, g2 = 2 )
summary( qapGcorResult )
plot( qapGcorResult )

# graph covariance...
graphCovariance <- sna::gcov( gmHumanNetworkMatrix, gw2HumanNetworkMatrix )
graphCovariance
paste( output_prefix, "graph covariance =", graphCovariance, sep = " " )

# try a qaptest...
qapGcovResult <- sna::qaptest( graphSetArray, sna::gcov, g1 = 1, g2 = 2 )
summary( qapGcovResult )
plot( qapGcovResult )

# Hamming Distance
graphHammingDist <- sna::hdist( gmHumanNetworkMatrix, gw2HumanNetworkMatrix )
paste( output_prefix, "graph hamming distance =", graphHammingDist, sep = " " )

# try a qaptest...
qapHdistResult <- sna::qaptest( graphSetArray, sna::hdist, g1 = 1, g2 = 2 )
summary( qapHdistResult )
plot( qapHdistResult )

# graph structural correlation?
#graphStructCorrelation <- gscor( gmHumanNetworkMatrix, gw2HumanNetworkMatrix )
#graphStructCorrelation
# Out:
# [1] "month-to-week_2 human graph correlation = 0.516410349744311"
# QAP Test Results
#
# Estimated p-values:
# 	p(f(perm) >= f(d)): 0
# 	p(f(perm) <= f(d)): 1
#
# Test Diagnostics:
# 	Test Value (f(d)): 0.5164103
# 	Replications: 1000
# 	Distribution Summary:
# 		Min:	 -0.0008052837
# 		1stQ:	 -0.0008052837
# 		Med:	 -0.0008052837
# 		Mean:	 5.523808e-06
# 		3rdQ:	 0.000566641
# 		Max:	 0.01291396
# [1] 0.0005532553
# [1] "month-to-week_2 human graph covariance = 0.00055325526146777"
# QAP Test Results
#
# Estimated p-values:
# 	p(f(perm) >= f(d)): 0
# 	p(f(perm) <= f(d)): 1
#
# Test Diagnostics:
# 	Test Value (f(d)): 0.0005532553
# 	Replications: 1000
# 	Distribution Summary:
# 		Min:	 -8.627392e-07
# 		1stQ:	 -8.627392e-07
# 		Med:	 -8.627392e-07
# 		Mean:	 1.032735e-08
# 		3rdQ:	 6.070698e-07
# 		Max:	 1.824478e-05
# Plot with title “Estimated Density of QAP Replications”
# [1] "month-to-week_2 human graph hamming distance = 2030"
# QAP Test Results
#
# Estimated p-values:
# 	p(f(perm) >= f(d)): 1
# 	p(f(perm) <= f(d)): 0
#
# Test Diagnostics:
# 	Test Value (f(d)): 2030
# 	Replications: 1000
# 	Distribution Summary:
# 		Min:	 3214
# 		1stQ:	 3238
# 		Med:	 3242
# 		Mean:	 3239.928
# 		3rdQ:	 3242
# 		Max:	 3242
# Plot with title “Estimated Density of QAP Replications”
# Plot with title “Estimated Density of QAP Replications”

# %% [markdown]
# # Compare `grp_month` and `grp_week_3` using QAP
#
# - Back to [Table of Contents](#Table-of-Contents)
#
# Now, compare the automated and human-coded networks from the full month and week 3 against each other, to see what more time gets you.
#
# Based on: `sourcenet/R/sna/statnet/sna-qap.r`

# %% [markdown]
# ## month-to-week_3 - automated
#
# - Back to [Table of Contents](#Table-of-Contents)

# %%
output_prefix <- "month-to-week_3 automated"

# %%
# link to good doc on qaptest(){sna} function: http://www.inside-r.org/packages/cran/sna/docs/qaptest

# First, need to load data - see (or just source() ) the file "sna-load_data.r".
# source( "sna-load_data.r" )
# does the following (among other things):
# Start with loading in tab-delimited files.
#humanNetworkData <- read.delim( "human-sourcenet_data-20150504-002453.tab", header = TRUE, row.names = 1, check.names = FALSE )
#calaisNetworkData <- read.delim( "puter-sourcenet_data-20150504-002507.tab", header = TRUE, row.names = 1, check.names = FALSE )

# remove the right-most column, which contains non-tie info on nodes.
#humanNetworkTies <- humanNetworkData[ , -ncol( humanNetworkData ) ]
#gw3AutomatedNetworkDF <- calaisNetworkData[ , -ncol( calaisNetworkData )]

# convert each to a matrix
#gw3HumanNetworkMatrix <- as.matrix( gw3HumanNetworkTies )
#gw3AutomatedNetworkMatrix <- as.matrix( gw3AutomatedNetworkDF )

# imports
# install.packages( "sna" )
# install.packages( "statnet" )
library( "sna" )

# package up data for calling qaptest() - first make 3-dimensional array to hold
#    our two matrices - this is known as a "graph set".
graphSetArray <- array( dim = c( 2, ncol( gmAutomatedNetworkMatrix ), nrow( gmAutomatedNetworkMatrix ) ) )

# then, place each matrix in one dimension of the array.
graphSetArray[ 1, , ] <- gmAutomatedNetworkMatrix
graphSetArray[ 2, , ] <- gw3AutomatedNetworkMatrix

# first, try a graph correlation
graphCorrelation <- sna::gcor( gmAutomatedNetworkMatrix, gw3AutomatedNetworkMatrix )
paste( output_prefix, "graph correlation =", graphCorrelation, sep = " " )

# try a qaptest...
qapGcorResult <- sna::qaptest( graphSetArray, sna::gcor, g1 = 1, g2 = 2 )
summary( qapGcorResult )
plot( qapGcorResult )

# graph covariance...
graphCovariance <- sna::gcov( gmAutomatedNetworkMatrix, gw3AutomatedNetworkMatrix )
graphCovariance
paste( output_prefix, "graph covariance =", graphCovariance, sep = " " )

# try a qaptest...
qapGcovResult <- sna::qaptest( graphSetArray, sna::gcov, g1 = 1, g2 = 2 )
summary( qapGcovResult )
plot( qapGcovResult )

# Hamming Distance
graphHammingDist <- sna::hdist( gmAutomatedNetworkMatrix, gw3AutomatedNetworkMatrix )
paste( output_prefix, "graph hamming distance =", graphHammingDist, sep = " " )

# try a qaptest...
qapHdistResult <- sna::qaptest( graphSetArray, sna::hdist, g1 = 1, g2 = 2 )
summary( qapHdistResult )
plot( qapHdistResult )

# graph structural correlation?
#graphStructCorrelation <- gscor( gw3HumanNetworkMatrix, gw3AutomatedNetworkMatrix )
#graphStructCorrelation
# Out:
# [1] "month-to-week_3 automated graph correlation = 0.449063768979808"
# QAP Test Results
#
# Estimated p-values:
# 	p(f(perm) >= f(d)): 0
# 	p(f(perm) <= f(d)): 1
#
# Test Diagnostics:
# 	Test Value (f(d)): 0.4490638
# 	Replications: 1000
# 	Distribution Summary:
# 		Min:	 -0.0007420192
# 		1stQ:	 -0.0007420192
# 		Med:	 -0.0007420192
# 		Mean:	 -2.484636e-05
# 		3rdQ:	 0.0008307283
# 		Max:	 0.007121718
# [1] 0.0004196719
# [1] "month-to-week_3 automated graph covariance = 0.000419671926779777"
# QAP Test Results
#
# Estimated p-values:
# 	p(f(perm) >= f(d)): 0
# 	p(f(perm) <= f(d)): 1
#
# Test Diagnostics:
# 	Test Value (f(d)): 0.0004196719
# 	Replications: 1000
# 	Distribution Summary:
# 		Min:	 -6.93453e-07
# 		1stQ:	 -6.93453e-07
# 		Med:	 -6.93453e-07
# 		Mean:	 1.031834e-07
# 		3rdQ:	 7.76356e-07
# 		Max:	 1.106502e-05
# Plot with title “Estimated Density of QAP Replications”
# [1] "month-to-week_3 automated graph hamming distance = 1984"
# QAP Test Results
#
# Estimated p-values:
# 	p(f(perm) >= f(d)): 1
# 	p(f(perm) <= f(d)): 0
#
# Test Diagnostics:
# 	Test Value (f(d)): 1984
# 	Replications: 1000
# 	Distribution Summary:
# 		Min:	 2996
# 		1stQ:	 3008
# 		Med:	 3012
# 		Mean:	 3010.368
# 		3rdQ:	 3012
# 		Max:	 3012
# Plot with title “Estimated Density of QAP Replications”
# Plot with title “Estimated Density of QAP Replications”

# %% [markdown]
# ## month-to-week_3 - human
#
# - Back to [Table of Contents](#Table-of-Contents)

# %%
output_prefix <- "month-to-week_3 human"

# %%
# link to good doc on qaptest(){sna} function: http://www.inside-r.org/packages/cran/sna/docs/qaptest

# First, need to load data - see (or just source() ) the file "sna-load_data.r".
# source( "sna-load_data.r" )
# does the following (among other things):
# Start with loading in tab-delimited files.
#humanNetworkData <- read.delim( "human-sourcenet_data-20150504-002453.tab", header = TRUE, row.names = 1, check.names = FALSE )
#calaisNetworkData <- read.delim( "puter-sourcenet_data-20150504-002507.tab", header = TRUE, row.names = 1, check.names = FALSE )

# remove the right-most column, which contains non-tie info on nodes.
#humanNetworkTies <- humanNetworkData[ , -ncol( humanNetworkData ) ]
#gw3HumanNetworkDF <- calaisNetworkData[ , -ncol( calaisNetworkData )]

# convert each to a matrix
#gw3HumanNetworkMatrix <- as.matrix( gw3HumanNetworkTies )
#gw3HumanNetworkMatrix <- as.matrix( gw3HumanNetworkDF )

# imports
# install.packages( "sna" )
# install.packages( "statnet" )
library( "sna" )

# package up data for calling qaptest() - first make 3-dimensional array to hold
#    our two matrices - this is known as a "graph set".
graphSetArray <- array( dim = c( 2, ncol( gmHumanNetworkMatrix ), nrow( gmHumanNetworkMatrix ) ) )

# then, place each matrix in one dimension of the array.
graphSetArray[ 1, , ] <- gmHumanNetworkMatrix
graphSetArray[ 2, , ] <- gw3HumanNetworkMatrix

# first, try a graph correlation
graphCorrelation <- sna::gcor( gmHumanNetworkMatrix, gw3HumanNetworkMatrix )
paste( output_prefix, "graph correlation =", graphCorrelation, sep = " " )

# try a qaptest...
qapGcorResult <- sna::qaptest( graphSetArray, sna::gcor, g1 = 1, g2 = 2 )
summary( qapGcorResult )
plot( qapGcorResult )

# graph covariance...
graphCovariance <- sna::gcov( gmHumanNetworkMatrix, gw3HumanNetworkMatrix )
graphCovariance
paste( output_prefix, "graph covariance =", graphCovariance, sep = " " )

# try a qaptest...
qapGcovResult <- sna::qaptest( graphSetArray, sna::gcov, g1 = 1, g2 = 2 )
summary( qapGcovResult )
plot( qapGcovResult )

# Hamming Distance
graphHammingDist <- sna::hdist( gmHumanNetworkMatrix, gw3HumanNetworkMatrix )
paste( output_prefix, "graph hamming distance =", graphHammingDist, sep = " " )

# try a qaptest...
qapHdistResult <- sna::qaptest( graphSetArray, sna::hdist, g1 = 1, g2 = 2 )
summary( qapHdistResult )
plot( qapHdistResult )

# graph structural correlation?
#graphStructCorrelation <- gscor( gmHumanNetworkMatrix, gw3HumanNetworkMatrix )
#graphStructCorrelation
# Out:
# [1] "month-to-week_3 human graph correlation = 0.44922480558016"
# QAP Test Results
#
# Estimated p-values:
# 	p(f(perm) >= f(d)): 0
# 	p(f(perm) <= f(d)): 1
#
# Test Diagnostics:
# 	Test Value (f(d)): 0.4492248
# 	Replications: 1000
# 	Distribution Summary:
# 		Min:	 -0.0007745641
# 		1stQ:	 -0.0007745641
# 		Med:	 -0.0007745641
# 		Mean:	 -1.177827e-05
# 		3rdQ:	 0.0007008437
# 		Max:	 0.0110287
# [1] 0.0004475201
# [1] "month-to-week_3 human graph covariance = 0.000447520126373497"
# QAP Test Results
#
# Estimated p-values:
# 	p(f(perm) >= f(d)): 0
# 	p(f(perm) <= f(d)): 1
#
# Test Diagnostics:
# 	Test Value (f(d)): 0.0004475201
# 	Replications: 1000
# 	Distribution Summary:
# 		Min:	 -7.716248e-07
# 		1stQ:	 -7.716248e-07
# 		Med:	 -7.716248e-07
# 		Mean:	 -2.496186e-08
# 		3rdQ:	 6.981842e-07
# 		Max:	 8.047229e-06
# Plot with title “Estimated Density of QAP Replications”
# [1] "month-to-week_3 human graph hamming distance = 2094"
# QAP Test Results
#
# Estimated p-values:
# 	p(f(perm) >= f(d)): 1
# 	p(f(perm) <= f(d)): 0
#
# Test Diagnostics:
# 	Test Value (f(d)): 2094
# 	Replications: 1000
# 	Distribution Summary:
# 		Min:	 3158
# 		1stQ:	 3174
# 		Med:	 3178
# 		Mean:	 3176.18
# 		3rdQ:	 3178
# 		Max:	 3178
# Plot with title “Estimated Density of QAP Replications”
# Plot with title “Estimated Density of QAP Replications”

# %% [markdown]
# # Save workspace image
#
# - Back to [Table of Contents](#Table-of-Contents)
#
# Save all the information in the current image, in case we need/want it later.

# %%
# help( save.image )
save.image( file = workspace_file_name )
